# %%
import xlrd
import os
import os.path
import nltk
from nltk import FreqDist
from nltk import bigrams
from nltk import ngrams
import gensim
import pyLDAvis
import pyLDAvis.gensim
import pandas

from gensim import corpora, models
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

pyLDAvis.enable_notebook()

# %%
stops = set(stopwords.words("english"))

# %%
fullText = []
for dirpath, dirnames, filenames in os.walk('/home/neil//Downloads'):
    for filename in [f for f in filenames if f.endswith(".xlsx")]:
        path = (os.path.join(dirpath, filename))
        book = xlrd.open_workbook(path)
        sheet = book.sheet_by_index(0)
        vals = sheet.col_values(1)
        fullText.extend(vals)
        print(path + " added")
# Out:
# /home/neil//Downloads/test.xlsx added
# /home/neil//Downloads/test (another copy).xlsx added
# /home/neil//Downloads/test (copy).xlsx added

# %%
texts = [[word for word in text.lower().split() if word not in stops] for text in fullText]
dictionary = corpora.Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
lda = gensim.models.ldamodel.LdaModel(corpus=corpus, id2word=dictionary, num_topics=5, passes=10)

# %%
Viewmodel = pyLDAvis.gensim.prepare(lda,corpus,dictionary)
Viewmodel
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 4      25.437251        1       1 -0.238808  0.089519
# 1      24.588824        1       2 -0.053711 -0.213344
# 0      19.034352        1       3  0.059446  0.115275
# 2      16.950150        1       4  0.147103  0.038134
# 3      13.989422        1       5  0.085969 -0.029584, topic_info=     Category       Freq         Term      Total  loglift  logprob
# term
# 756   Default  47.000000         page  47.000000  30.0000  30.0000
# 255   Default  35.000000         main  35.000000  29.0000  29.0000
# 60    Default  37.000000       design  37.000000  28.0000  28.0000
# 130   Default  26.000000        would  26.000000  27.0000  27.0000
# 673   Default  30.000000         easy  30.000000  26.0000  26.0000
# 121   Default  23.000000        color  23.000000  25.0000  25.0000
# 541   Default  28.000000        site.  28.000000  24.0000  24.0000
# 339   Default  26.000000         feel  26.000000  23.0000  23.0000
# 112   Default  16.000000        makes  16.000000  22.0000  22.0000
# 170   Default  45.000000        links  45.000000  21.0000  21.0000
# 630   Default  32.000000         well  32.000000  20.0000  20.0000
# 581   Default  20.000000     graphics  20.000000  19.0000  19.0000
# 578   Default  25.000000        great  25.000000  18.0000  18.0000
# 463   Default  18.000000       layout  18.000000  17.0000  17.0000
# 612   Default  10.000000        site,  10.000000  16.0000  16.0000
# 102   Default  18.000000    technical  18.000000  15.0000  15.0000
# 784   Default  13.000000       appeal  13.000000  14.0000  14.0000
# 292   Default  13.000000         idea  13.000000  13.0000  13.0000
# 180   Default  20.000000  information  20.000000  12.0000  12.0000
# 442   Default   8.000000        clean   8.000000  11.0000  11.0000
# 720   Default  10.000000        small  10.000000  10.0000  10.0000
# 531   Default  13.000000   navigation  13.000000   9.0000   9.0000
# 334   Default   8.000000        first   8.000000   8.0000   8.0000
# 2     Default  15.000000    excellent  15.000000   7.0000   7.0000
# 454   Default  15.000000       colors  15.000000   6.0000   6.0000
# 549   Default  15.000000        page.  15.000000   5.0000   5.0000
# 400   Default  13.000000         need  13.000000   4.0000   4.0000
# 186   Default  17.000000        thing  17.000000   3.0000   3.0000
# 333   Default   8.000000        think   8.000000   2.0000   2.0000
# 93    Default  11.000000          web  11.000000   1.0000   1.0000
# ...       ...        ...          ...        ...      ...      ...
# 240    Topic5   2.600118         for.   3.274424   1.7363  -5.5013
# 824    Topic5   2.600117       words,   3.274424   1.7363  -5.5013
# 152    Topic5   2.600117     quickly.   3.274424   1.7363  -5.5013
# 449    Topic5   2.600117         show   3.274424   1.7363  -5.5013
# 225    Topic5   2.600116      looking   3.274424   1.7363  -5.5013
# 255    Topic5  23.678082         main  35.159520   1.5715  -3.2923
# 720    Topic5   7.465233        small  10.657196   1.6109  -4.4466
# 756    Topic5  27.898506         page  47.662944   1.4313  -3.1283
# 361    Topic5   5.040639       scheme   8.218876   1.4780  -4.8394
# 106    Topic5   5.022946       amount   8.219729   1.4743  -4.8429
# 575    Topic5   5.042109        liven   8.277878   1.4711  -4.8391
# 47     Topic5   5.028996        loads   8.278808   1.4684  -4.8417
# 367    Topic5   6.951562          lot  13.181639   1.3270  -4.5179
# 121    Topic5   9.767438        color  23.187590   1.1023  -4.1778
# 66     Topic5   4.864242         font   8.227577   1.4413  -4.8750
# 553    Topic5   7.485182       simple  18.148043   1.0812  -4.4440
# 414    Topic5   4.594659         also   8.316558   1.3735  -4.9320
# 327    Topic5   5.042740        place  10.783559   1.2068  -4.8389
# 450    Topic5   7.149211         text  28.101965   0.5980  -4.4899
# 139    Topic5   4.987795         tell  13.402131   0.9784  -4.8499
# 60     Topic5   7.477189       design  37.351922   0.3583  -4.4450
# 649    Topic5   4.240263         rest  10.599108   1.0507  -5.0123
# 598    Topic5   9.327708         site  79.919793  -0.1812  -4.2239
# 855    Topic5   4.391204         time  13.271264   0.8609  -4.9773
# 581    Topic5   5.059070     graphics  20.205690   0.5821  -4.8357
# 785    Topic5   5.068607          way  26.271280   0.3215  -4.8338
# 148    Topic5   4.080544         warm  13.448777   0.7742  -5.0507
# 548    Topic5   4.192150         load  15.847843   0.6370  -5.0237
# 630    Topic5   4.979335         well  32.663790   0.0859  -4.8516
# 170    Topic5   3.031147        links  45.284999  -0.7372  -5.3480
#
# [304 rows x 6 columns], token_table=      Topic      Freq         Term
# term
# 696       2  0.881649         "and
# 82        5  0.916192     "sahara"
# 571       2  0.881649       'great
# 411       1  0.861121         able
# 110       4  0.928791       added.
# 805       1  0.578850   admiration
# 805       3  0.347310   admiration
# 414       1  0.120242         also
# 414       2  0.360726         also
# 414       5  0.601210         also
# 282       3  0.897246        also,
# 106       3  0.364976       amount
# 106       5  0.608293       amount
# 358       2  0.881649       anyone
# 753       1  0.861121     anything
# 784       2  0.951312       appeal
# 773       3  0.854690  appropriate
# 6         1  0.815945    arranging
# 436       2  0.732123      average
# 436       4  0.274546      average
# 687       2  0.732196   background
# 687       4  0.274574   background
# 410       3  0.897246  banner/logo
# 490       3  0.897246          bar
# 725       4  0.928791      before.
# 369       2  0.881649       behind
# 0         4  0.928791      better!
# 683       5  0.916192          big
# 722       1  0.861121        birth
# 690       4  0.871639          bit
# ...     ...       ...          ...
# 148       2  0.669206         warm
# 148       5  0.297425         warm
# 691       3  0.176420   washed-out
# 691       4  0.705678   washed-out
# 785       1  0.418708          way
# 785       2  0.114193          way
# 785       3  0.190322          way
# 785       4  0.114193          way
# 785       5  0.190322          way
# 93        1  0.963144          web
# 342       2  0.881649      welcome
# 630       2  0.153075         well
# 630       3  0.183690         well
# 630       4  0.489839         well
# 630       5  0.153075         well
# 360       5  0.916192        white
# 770       1  0.861121       within
# 824       5  0.916192       words,
# 158       1  0.861121         work
# 583       1  0.269716       worked
# 583       2  0.449526       worked
# 583       3  0.269716       worked
# 311       2  0.837799      working
# 130       1  0.187574        would
# 130       2  0.787811        would
# 593       4  0.889160     written.
# 791       5  0.916192       yellow
# 251       5  0.916192      yellow,
# 658       1  0.705291          yet
# 658       2  0.264484          yet
#
# [392 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[5, 2, 1, 3, 4])

# %%
string = ' '.join(fullText).replace(".", "").replace(",", "").replace("\n", "").lower()
list2=string.split()
filtered =list(filter(lambda x: x not in stops,list2))
words = ' '.join(filtered)

tokens = nltk.word_tokenize(words)
text = nltk.Text(tokens)

# %%
n = 8
bgs = ngrams(tokens, n)
fdist1 = FreqDist(bgs)

# %%
fdist1.most_common()
#for word, frequency in fdist.most_common(50):
    #print(u'{};{}'.format(word, frequency))
# Out:
# [((u'pages',
#    u'try',
#    u'keep',
#    u'consistent',
#    u'main',
#    u'page',
#    u'links',
#    u'left'),
#   3),
#  ((u'fine',
#    u'age',
#    u'tell',
#    u'families',
#    u'pleasant',
#    u'speaking',
#    u'bringing',
#    u'thoughts'),
#   3),
#  ((u'site',
#    u'feels',
#    u'great',
#    u'suggest',
#    u'change',
#    u'fonts',
#    u'arial',
#    u'rounded'),
#   3),
#  ((u'world',
#    u'chief',
#    u'means',
#    u'weeks',
#    u'smile',
#    u'design',
#    u'professional',
#    u'well'),
#   3),
#  ((u'much',
#    u'text',
#    u'first',
#    u'page',
#    u'also',
#    u'comforts',
#    u'reader',
#    u'way'),
#   3),
#  ((u'making',
#    u'text',
#    u'buttons',
#    u'light',
#    u'warm',
#    u'shade',
#    u'make',
#    u'shadow'),
#   3),
#  ((u'confusing',
#    u'reader',
#    u'search',
#    u'first',
#    u'page',
#    u'find',
#    u'looking',
#    u'sitemap'),
#   3),
#  ((u'graphics',
#    u'significant',
#    u'effective',
#    u'easy',
#    u'navigate',
#    u'site',
#    u'know',
#    u'links'),
#   3),
#  ((u'far',
#    u'immediate',
#    u'sweetness',
#    u'earnestly',
#    u'dejection',
#    u'four',
#    u'love',
#    u'settling'),
#   3),
#  ((u'sahara',
#    u"''",
#    u'title',
#    u'liven',
#    u'pages',
#    u'bit',
#    u'small',
#    u'amount'),
#   3),
#  ((u'thing',
#    u'seems',
#    u'like',
#    u'y2k',
#    u'effected',
#    u'date',
#    u'counter',
#    u'!'),
#   3),
#  ((u'always', u"'great", u'site', u'factor', u"'", u'read', u'whole', u'site'),
#   3),
#  ((u'good',
#    u'reputation',
#    u'!',
#    u'easy',
#    u'navigate',
#    u'links',
#    u'arranged',
#    u'appropriately'),
#   3),
#  ((u'liven',
#    u'site',
#    u'content',
#    u'flows',
#    u'well',
#    u'everything',
#    u'appropriate',
#    u'place'),
#   3),
#  ((u'design',
#    u'edward',
#    u'regret',
#    u'met',
#    u'lovers',
#    u'calm',
#    u'case',
#    u'roof'),
#   3),
#  ((u'right',
#    u'bottom',
#    u'top',
#    u'said',
#    u'boxed-in',
#    u'thing',
#    u'good',
#    u'bit'),
#   3),
#  ((u'tab', u'top', u'links', u'sit', u'it', u"'s", u'clever', u'idea'), 3),
#  ((u'could',
#    u'animate',
#    u'site',
#    u'logo',
#    u'!',
#    u'extremely',
#    u'easy',
#    u'navigate'),
#   3),
#  ((u'narrow',
#    u'afraid',
#    u'could',
#    u'merit',
#    u'keeps',
#    u'child',
#    u'dried',
#    u'maids'),
#   3),
#  ((u'wwwcharityfocusorg/host/calpep/',
#    u'site',
#    u'would',
#    u'appeal',
#    u'average',
#    u'person',
#    u'way',
#    u'simply'),
#   3),
#  ((u'reader',
#    u'plus',
#    u'simple',
#    u'much',
#    u'text',
#    u'first',
#    u'page',
#    u'also'),
#   3),
#  ((u'effective',
#    u'clean',
#    u'site',
#    u'flawless',
#    u'look',
#    u'someone',
#    u'without',
#    u'technical'),
#   3),
#  ((u'simplest',
#    u'way',
#    u'possible',
#    u'people',
#    u'technical',
#    u'back',
#    u'ground',
#    u'would'),
#   3),
#  ((u'great',
#    u'adds',
#    u'life',
#    u'site',
#    u'stops',
#    u'moving',
#    u'annoying',
#    u'least'),
#   3),
#  ((u'title',
#    u'would',
#    u'leave',
#    u'way',
#    u'really',
#    u'adds',
#    u'site',
#    u'found'),
#   3),
#  ((u'think', u'image', u'put', u'place', u'words', u'style', u'``', u'sahara'),
#   3),
#  ((u'understand', u'read', u'it', u"'s", u'great', u'way', u'main', u'page'),
#   3),
#  ((u'uneasy',
#    u'settle',
#    u'whence',
#    u'nature',
#    u'narrow',
#    u'afraid',
#    u'could',
#    u'merit'),
#   3),
#  ((u'flawless',
#    u'look',
#    u'someone',
#    u'without',
#    u'technical',
#    u'background',
#    u'would',
#    u'definitely'),
#   3),
#  ((u'logo',
#    u'present',
#    u'excellent',
#    u'site',
#    u'simple',
#    u'design',
#    u'informative-',
#    u'great'),
#   3),
#  ((u'talking',
#    u'delight',
#    u'dare',
#    u'feet',
#    u'tell',
#    u'busy',
#    u'considered',
#    u'imprudence'),
#   3),
#  ((u'warm',
#    u'inviting',
#    u'first',
#    u'entered',
#    u'site',
#    u'could',
#    u'tell',
#    u'lot'),
#   3),
#  ((u'link',
#    u'buttons',
#    u'find',
#    u'typos',
#    u'broken',
#    u'links',
#    u'well',
#    u'written'),
#   3),
#  ((u'excuse',
#    u'chatty',
#    u'seemed',
#    u'warmth',
#    u'nay',
#    u'add',
#    u'far',
#    u'immediate'),
#   3),
#  ((u'celebrated',
#    u'delightful',
#    u'especially',
#    u'increasing',
#    u'instrument',
#    u'indulgence',
#    u'contrasted',
#    u'sufficient'),
#   3),
#  ((u'like',
#    u'said',
#    u'bit',
#    u'bland',
#    u'think',
#    u'adding',
#    u'colors',
#    u'graphics'),
#   3),
#  ((u'tags',
#    u'needs',
#    u'fixed',
#    u'main',
#    u'page',
#    u'linked',
#    u'charityfocus',
#    u'logo'),
#   3),
#  ((u'section',
#    u'need',
#    u'front',
#    u'page',
#    u'interesting',
#    u'information',
#    u'get',
#    u'viewer'),
#   3),
#  ((u'shameless',
#    u'middleton',
#    u'agreement',
#    u'found',
#    u'world',
#    u'chief',
#    u'means',
#    u'weeks'),
#   3),
#  ((u'go',
#    u'professional',
#    u'feel',
#    u'site',
#    u'minimum',
#    u'graphics',
#    u'graphics',
#    u'small'),
#   3),
#  ((u'worked',
#    u'bit',
#    u'design',
#    u'classic-',
#    u'like',
#    u'said',
#    u'bit',
#    u'bland'),
#   3),
#  ((u'regret',
#    u'met',
#    u'lovers',
#    u'calm',
#    u'case',
#    u'roof',
#    u'allowance',
#    u'instantly'),
#   3),
#  ((u'dried', u'quick', u'round', u'order', u'add', u'past', u'see', u'west'),
#   3),
#  ((u'typos',
#    u'spelling',
#    u'mistakes',
#    u'within',
#    u'pages',
#    u'checked',
#    u'hyperlinks',
#    u'found'),
#   3),
#  ((u'say',
#    u'stimulated',
#    u'certain',
#    u'forbade',
#    u'picture',
#    u'prevent',
#    u'carried',
#    u'get'),
#   3),
#  ((u'color',
#    u'scheme',
#    u'goes',
#    u'together',
#    u'well',
#    u'contents',
#    u'pages',
#    u'flows'),
#   3),
#  ((u'amount',
#    u'images',
#    u'page',
#    u'loads',
#    u'quickly',
#    u'thing',
#    u'slows',
#    u'load'),
#   3),
#  ((u'needs',
#    u'worked',
#    u'little',
#    u'glitches',
#    u'well',
#    u'done',
#    u'!',
#    u'web'),
#   3),
#  ((u'side',
#    u'good',
#    u'except',
#    u'mouse-over',
#    u'image',
#    u'doesnt',
#    u'really',
#    u'go'),
#   3),
#  ((u'main',
#    u'page',
#    u'linked',
#    u'charityfocus',
#    u'logo',
#    u'site',
#    u'informative',
#    u'easy'),
#   3),
#  ((u'navigation',
#    u'bar',
#    u'perhaps',
#    u'main',
#    u'colors',
#    u'perfect',
#    u'warm',
#    u'inviting'),
#   3),
#  ((u'seemed',
#    u'warmth',
#    u'nay',
#    u'add',
#    u'far',
#    u'immediate',
#    u'sweetness',
#    u'earnestly'),
#   3),
#  ((u'links', u'left', u'hand', u'side', u'rest', u'pages', u'try', u'keep'),
#   3),
#  ((u'behind',
#    u'links',
#    u'site',
#    u'feels',
#    u'great',
#    u'suggest',
#    u'change',
#    u'fonts'),
#   3),
#  ((u'charityfocus',
#    u'text',
#    u'cf',
#    u'logo',
#    u'present',
#    u'excellent',
#    u'site',
#    u'simple'),
#   3),
#  ((u'see',
#    u'suggest',
#    u'make',
#    u'link',
#    u'text',
#    u'slightly',
#    u'larger',
#    u'make'),
#   3),
#  ((u'overwhelmed',
#    u'information',
#    u'presentation',
#    u'site',
#    u'needs',
#    u'worked',
#    u'bit',
#    u'design'),
#   3),
#  ((u'animated',
#    u'title',
#    u'would',
#    u'leave',
#    u'way',
#    u'really',
#    u'adds',
#    u'site'),
#   3),
#  ((u'commanded',
#    u'consisted',
#    u'disposing',
#    u'engrossed',
#    u'tall',
#    u'snug',
#    u'till',
#    u'easy'),
#   3),
#  ((u'unpleasant',
#    u'insensible',
#    u'favourable',
#    u'latter',
#    u'remark',
#    u'hunted',
#    u'enough',
#    u'vulgar'),
#   3),
#  ((u'text',
#    u'better',
#    u'!',
#    u'design',
#    u'consistent-',
#    u'simple',
#    u'yellow',
#    u'green'),
#   3),
#  ((u'links',
#    u'left',
#    u'hand',
#    u'side',
#    u'good',
#    u'except',
#    u'mouse-over',
#    u'image'),
#   3),
#  ((u'images',
#    u'page',
#    u'loads',
#    u'quickly',
#    u'thing',
#    u'slows',
#    u'load',
#    u'time'),
#   3),
#  ((u'good',
#    u'hands',
#    u'know',
#    u'able',
#    u'find',
#    u'anything',
#    u'need',
#    u'site'),
#   3),
#  ((u'adding',
#    u'colors',
#    u'graphics',
#    u'site',
#    u'liven',
#    u'bit',
#    u'perhaps',
#    u'make'),
#   3),
#  ((u'feel',
#    u'overwhelmed',
#    u'information',
#    u'presentation',
#    u'site',
#    u'needs',
#    u'worked',
#    u'bit'),
#   3),
#  ((u'shadow',
#    u'different',
#    u'softer',
#    u'color',
#    u'site',
#    u'mostly',
#    u'easy',
#    u'navigate'),
#   3),
#  ((u"n't",
#    u'go',
#    u'another',
#    u'page',
#    u'layout',
#    u'makes',
#    u'feel',
#    u'comfortable'),
#   3),
#  ((u'essential',
#    u'good',
#    u'site',
#    u'good',
#    u'idea',
#    u'highlights',
#    u'section',
#    u'right'),
#   3),
#  ((u'design',
#    u'excellent',
#    u'content',
#    u'well',
#    u'great',
#    u'job',
#    u'everyone',
#    u'involved'),
#   3),
#  ((u'site',
#    u'review',
#    u'cal-pep',
#    u'wwwcharityfocusorg/host/calpep/',
#    u'site',
#    u'would',
#    u'appeal',
#    u'average'),
#   3),
#  ((u'purples',
#    u'create',
#    u'comforting',
#    u'feeling',
#    u'reader',
#    u'plus',
#    u'simple',
#    u'much'),
#   3),
#  ((u'fine', u'great', u'job', u'!', u'meta', u'tags', u'present', u'pages'),
#   3),
#  ((u'typos',
#    u'broken',
#    u'links',
#    u'well',
#    u'written',
#    u'information',
#    u'!',
#    u'sufficient'),
#   3),
#  ((u'easy', u'understand', u'read', u'it', u"'s", u'great', u'way', u'main'),
#   3),
#  ((u'technical',
#    u'background',
#    u'simple',
#    u'effective',
#    u'washed-out',
#    u'image',
#    u'tiled',
#    u'background'),
#   3),
#  ((u'alternative',
#    u'form',
#    u'getting',
#    u'around',
#    u'someone',
#    u'browser',
#    u'does',
#    u"n't"),
#   3),
#  ((u'without',
#    u'started',
#    u'residence',
#    u'gentleman',
#    u'yet',
#    u'preserved',
#    u'convinced',
#    u'coming'),
#   3),
#  ((u'written',
#    u'information',
#    u'appropriate',
#    u'place',
#    u'thing',
#    u'content',
#    u'amount',
#    u'front'),
#   3),
#  ((u'found',
#    u'typos',
#    u'except',
#    u'missing',
#    u'period',
#    u'end',
#    u'text',
#    u'main'),
#   3),
#  ((u'idea',
#    u'links',
#    u'left',
#    u'hand',
#    u'side',
#    u'good',
#    u'except',
#    u'mouse-over'),
#   3),
#  ((u'boisterous',
#    u'say',
#    u'stimulated',
#    u'certain',
#    u'forbade',
#    u'picture',
#    u'prevent',
#    u'carried'),
#   3),
#  ((u'errors', u'except', u'one', u'main', u'page', u':', u'``', u'and'), 3),
#  ((u'may', u'day', u'evening', u'way', u'luckily', u'son', u'exposed', u'get'),
#   3),
#  ((u'enabled',
#    u'attempt',
#    u'talking',
#    u'delight',
#    u'dare',
#    u'feet',
#    u'tell',
#    u'busy'),
#   3),
#  ((u'honoured',
#    u'speaking',
#    u'replying',
#    u'mistress',
#    u'numerous',
#    u'returned',
#    u'feelings',
#    u'may'),
#   3),
#  ((u'bit',
#    u'small',
#    u'amount',
#    u'images',
#    u'page',
#    u'loads',
#    u'quickly',
#    u'thing'),
#   3),
#  ((u'warmth',
#    u'nay',
#    u'add',
#    u'far',
#    u'immediate',
#    u'sweetness',
#    u'earnestly',
#    u'dejection'),
#   3),
#  ((u'average',
#    u'persons',
#    u'experience',
#    u'oh',
#    u'one',
#    u'thing',
#    u'seems',
#    u'like'),
#   3),
#  ((u'try',
#    u'keep',
#    u'consistent',
#    u'main',
#    u'page',
#    u'links',
#    u'left',
#    u'right'),
#   3),
#  ((u'content',
#    u'flows',
#    u'well',
#    u'well',
#    u'written',
#    u'information',
#    u'appropriate',
#    u'place'),
#   3),
#  ((u'site',
#    u'show',
#    u'also',
#    u'liven',
#    u'site',
#    u'content',
#    u'flows',
#    u'well'),
#   3),
#  ((u'experience',
#    u'oh',
#    u'one',
#    u'thing',
#    u'seems',
#    u'like',
#    u'y2k',
#    u'effected'),
#   3),
#  ((u'yellow',
#    u'green',
#    u'black',
#    u'used',
#    u'every',
#    u'page',
#    u'left',
#    u'font'),
#   3),
#  ((u'talking',
#    u'friendly',
#    u'way',
#    u'design',
#    u'excellent-',
#    u'simple',
#    u'point',
#    u'right'),
#   3),
#  ((u'sitemap',
#    u'excellent',
#    u'idea',
#    u'site',
#    u'suggest',
#    u'put',
#    u'link',
#    u'obvious'),
#   3),
#  ((u'background',
#    u'easily',
#    u'see',
#    u'layout',
#    u'makes',
#    u'feel',
#    u'comfortable',
#    u'especially'),
#   3),
#  ((u'main',
#    u'page',
#    u'sub',
#    u'pages',
#    u'overall',
#    u'great',
#    u'site',
#    u'great'),
#   3),
#  ((u'well',
#    u'done',
#    u'design',
#    u'effective',
#    u'like',
#    u'way',
#    u'added',
#    u'little'),
#   3),
#  ((u'well',
#    u'done',
#    u'clean',
#    u'looking',
#    u'feel',
#    u'good',
#    u'hands',
#    u'know'),
#   3),
#  ((u'graphics',
#    u'colors',
#    u'great',
#    u'purples',
#    u'excellent',
#    u'choice',
#    u'site',
#    u'perhaps'),
#   3),
#  ((u'settle',
#    u'whence',
#    u'nature',
#    u'narrow',
#    u'afraid',
#    u'could',
#    u'merit',
#    u'keeps'),
#   3),
#  ((u'icon',
#    u'navigation',
#    u'bar',
#    u'every',
#    u'site',
#    u'way',
#    u'reader',
#    u'knows'),
#   3),
#  ((u'site', u'factor', u"'", u'read', u'whole', u'site', u'find', u'spelling'),
#   3),
#  ((u'charityfocus',
#    u'logo',
#    u'present',
#    u'web',
#    u'site',
#    u'review',
#    u'cal-pep',
#    u'wwwcharityfocusorg/host/calpep/'),
#   3),
#  ((u'suspected',
#    u'perpetual',
#    u'power',
#    u'dried',
#    u'taken',
#    u'place',
#    u'day',
#    u'ought'),
#   3),
#  ((u'inviting',
#    u'first',
#    u'entered',
#    u'site',
#    u'could',
#    u'tell',
#    u'lot',
#    u'thought'),
#   3),
#  ((u'yet',
#    u'kindness',
#    u'replying',
#    u'whatever',
#    u'marianne',
#    u'old',
#    u'sentiments',
#    u'resolution'),
#   3),
#  ((u'kind',
#    u'bland',
#    u'makes',
#    u'feel',
#    u'comfortable',
#    u'site',
#    u'do',
#    u"n't"),
#   3),
#  ((u"'s", u'easy', u'understand', u'read', u'it', u"'s", u'great', u'way'), 3),
#  ((u'done',
#    u'design',
#    u'effective',
#    u'like',
#    u'way',
#    u'added',
#    u'little',
#    u'tab'),
#   3),
#  ((u':', u'``', u'and', u'peer', u'threatment', u'advocacy', u"''", u'remove'),
#   3),
#  ((u'engrossed', u'tall', u'snug', u'till', u'easy', u'form', u'calm', u'new'),
#   3),
#  ((u'started',
#    u'residence',
#    u'gentleman',
#    u'yet',
#    u'preserved',
#    u'convinced',
#    u'coming',
#    u'regret'),
#   3),
#  ((u'simple',
#    u'yellow',
#    u'green',
#    u'black',
#    u'used',
#    u'every',
#    u'page',
#    u'left'),
#   3),
#  ((u'feel',
#    u'comfortable',
#    u'site',
#    u'said',
#    u'it',
#    u"'s",
#    u'simple-',
#    u'title'),
#   3),
#  ((u'worked', u'little', u'glitches', u'well', u'done', u'!', u'web', u'site'),
#   3),
#  ((u'tags',
#    u'really',
#    u'need',
#    u'added',
#    u'technical',
#    u'branding',
#    u'done',
#    u'page'),
#   3),
#  ((u'logo',
#    u'link',
#    u'buttons',
#    u'fast',
#    u'load',
#    u'time',
#    u'always',
#    u"'great"),
#   3),
#  ((u'quickly',
#    u'thing',
#    u'slows',
#    u'load',
#    u'time',
#    u'animated',
#    u'title',
#    u'would'),
#   3),
#  ((u'stand', u'lot', u'rest', u'text', u'great-', u'easy', u'see', u'suggest'),
#   3),
#  ((u'page',
#    u'loads',
#    u'quickly',
#    u'thing',
#    u'slows',
#    u'load',
#    u'time',
#    u'animated'),
#   3),
#  ((u'simple',
#    u'much',
#    u'text',
#    u'first',
#    u'page',
#    u'also',
#    u'comforts',
#    u'reader'),
#   3),
#  ((u'surprise',
#    u'honoured',
#    u'speaking',
#    u'replying',
#    u'mistress',
#    u'numerous',
#    u'returned',
#    u'feelings'),
#   3),
#  ((u'order', u'add', u'past', u'see', u'west', u'felt', u'say', u'noise'), 3),
#  ((u'shade',
#    u'make',
#    u'shadow',
#    u'different',
#    u'softer',
#    u'color',
#    u'site',
#    u'mostly'),
#   3),
#  ((u'looking',
#    u'feel',
#    u'good',
#    u'hands',
#    u'know',
#    u'able',
#    u'find',
#    u'anything'),
#   3),
#  ((u'dried', u'taken', u'place', u'day', u'ought', u'four', u'ham', u'west'),
#   3),
#  ((u'carried',
#    u'get',
#    u'see',
#    u'sitting',
#    u'twenty',
#    u'limits',
#    u'months',
#    u'inhabit'),
#   3),
#  ((u'globe',
#    u'left',
#    u'behind',
#    u'links',
#    u'site',
#    u'feels',
#    u'great',
#    u'suggest'),
#   3),
#  ((u'go',
#    u'well',
#    u'together',
#    u'purple',
#    u'color',
#    u'accessed',
#    u'links',
#    u'nice'),
#   3),
#  ((u'ladies', u'houses', u'oh', u'eldest', u'gone', u'pure', u'late', u'gay'),
#   3),
#  ((u'love',
#    u'washed-out',
#    u'image',
#    u'globe',
#    u'left',
#    u'behind',
#    u'links',
#    u'site'),
#   3),
#  ((u'immediate',
#    u'saw',
#    u'one',
#    u'day',
#    u'perceived',
#    u'old',
#    u'blushes',
#    u'respect'),
#   3),
#  ((u'coming',
#    u'regret',
#    u'simple',
#    u'longer',
#    u'little',
#    u'sister',
#    u'danger',
#    u'adieus'),
#   3),
#  ((u'main', u'page', u'handy', u'useful', u'also', u'do', u"n't", u'go'), 3),
#  ((u'add',
#    u'far',
#    u'immediate',
#    u'sweetness',
#    u'earnestly',
#    u'dejection',
#    u'four',
#    u'love'),
#   3),
#  ((u'graceful',
#    u'dissuade',
#    u'new',
#    u'outlived',
#    u'prospect',
#    u'followed',
#    u'uneasy',
#    u'settle'),
#   3),
#  ((u'someone',
#    u'did',
#    u"n't",
#    u'technical',
#    u'background',
#    u'there',
#    u"'s",
#    u'high-tech'),
#   3),
#  ((u'get',
#    u'general',
#    u'greatly',
#    u'zealously',
#    u'prevailed',
#    u'arranging',
#    u'set',
#    u'arranging'),
#   3),
#  ((u"'s",
#    u'high-tech',
#    u'stuff',
#    u'information',
#    u'need',
#    u'great',
#    u'design',
#    u'that'),
#   3),
#  ((u'excellent',
#    u'site',
#    u'simple',
#    u'design',
#    u'informative-',
#    u'great',
#    u'work',
#    u'!'),
#   3),
#  ((u'purpose',
#    u'mentioned',
#    u'boxed-in',
#    u'layout',
#    u'makes',
#    u'feel',
#    u'comfortable',
#    u'graphics'),
#   3),
#  ((u'therefore',
#    u'attachment',
#    u'companions',
#    u'man',
#    u'way',
#    u'excellence',
#    u'pianoforte',
#    u'smallest'),
#   3),
#  ((u'right',
#    u'left',
#    u'excellent',
#    u'one',
#    u'thing',
#    u'navigation',
#    u'alternative',
#    u'form'),
#   3),
#  ((u'spelling',
#    u'typing',
#    u'errors',
#    u'except',
#    u'one',
#    u'main',
#    u'page',
#    u':'),
#   3),
#  ((u'site',
#    u'great',
#    u'design',
#    u'excellent',
#    u'content',
#    u'well',
#    u'great',
#    u'job'),
#   3),
#  ((u'linked',
#    u'charityfocus',
#    u'text',
#    u'cf',
#    u'logo',
#    u'present',
#    u'excellent',
#    u'site'),
#   3),
#  ((u'work',
#    u'well',
#    u'meta',
#    u'tags',
#    u'really',
#    u'need',
#    u'added',
#    u'technical'),
#   3),
#  ((u'using',
#    u'bold',
#    u'pink/purple',
#    u'color',
#    u'links',
#    u'perhaps',
#    u'make',
#    u'button'),
#   3),
#  ((u'suggest',
#    u'make',
#    u'link',
#    u'text',
#    u'slightly',
#    u'larger',
#    u'make',
#    u'stand'),
#   3),
#  ((u'title',
#    u'links',
#    u'text',
#    u'well',
#    u'done',
#    u'design',
#    u'effective',
#    u'like'),
#   3),
#  ((u'worked', u'fine', u'great', u'job', u'!', u'meta', u'tags', u'present'),
#   3),
#  ((u'life',
#    u'site',
#    u'stops',
#    u'moving',
#    u'annoying',
#    u'least',
#    u'graphics',
#    u'kept'),
#   3),
#  ((u'pink/purple',
#    u'color',
#    u'links',
#    u'perhaps',
#    u'make',
#    u'button',
#    u'graphics',
#    u'colors'),
#   3),
#  ((u'present',
#    u'excellent',
#    u'site',
#    u'simple',
#    u'design',
#    u'informative-',
#    u'great',
#    u'work'),
#   3),
#  ((u'minimum', u'text', u'main', u'page', u'great', u';', u'big', u'chunk'),
#   3),
#  ((u'bit',
#    u'bland',
#    u'think',
#    u'adding',
#    u'colors',
#    u'graphics',
#    u'site',
#    u'liven'),
#   3),
#  ((u'good',
#    u'idea',
#    u'highlights',
#    u'section',
#    u'right',
#    u'middle',
#    u'screen',
#    u'obvious'),
#   3),
#  ((u'site',
#    u'review',
#    u'sahara',
#    u'wwwcharityfocusorg/host/sahara',
#    u'site',
#    u"'s",
#    u'simple',
#    u'layout'),
#   3),
#  ((u'browser',
#    u'does',
#    u"n't",
#    u'load',
#    u'graphics',
#    u'would',
#    u'difficult',
#    u'get'),
#   3),
#  ((u'links',
#    u'really',
#    u'adds',
#    u'ease',
#    u'navigation',
#    u'color',
#    u'links',
#    u'makes'),
#   3),
#  ((u'appropriately',
#    u'left',
#    u'thing',
#    u'could',
#    u'changed',
#    u'links',
#    u'size',
#    u'color'),
#   3),
#  ((u'messing',
#    u'around',
#    u'information',
#    u'want',
#    u'convey',
#    u'presented',
#    u'simplest',
#    u'way'),
#   3),
#  ((u"n't", u'think', u'i', u"'ve", u'seen', u'animated', u'logo', u'great'),
#   3),
#  ((u'easy', u'read-', u'less', u'huge', u'chunks', u'text', u'better', u'!'),
#   3),
#  ((u'sorry',
#    u'!',
#    u'overall',
#    u'excellent',
#    u'page',
#    u'lots',
#    u'heart',
#    u'love'),
#   3),
#  ((u'equal',
#    u'old',
#    u'fanny',
#    u'charm',
#    u'difficulty',
#    u'invitation',
#    u'put',
#    u'introduced'),
#   3),
#  ((u'writer',
#    u'talking',
#    u'friendly',
#    u'way',
#    u'design',
#    u'excellent-',
#    u'simple',
#    u'point'),
#   3),
#  ((u'excellent',
#    u'idea',
#    u'site',
#    u'suggest',
#    u'put',
#    u'link',
#    u'obvious',
#    u'place'),
#   3),
#  ((u'quite',
#    u'quickly',
#    u'great',
#    u'find',
#    u'typos',
#    u'spelling',
#    u'mistakes',
#    u'within'),
#   3),
#  ((u'main', u'page', u'links', u'left', u'hand', u'side', u'rest', u'pages'),
#   3),
#  ((u'sufficient',
#    u'unpleasant',
#    u'insensible',
#    u'favourable',
#    u'latter',
#    u'remark',
#    u'hunted',
#    u'enough'),
#   3),
#  ((u'small',
#    u'amount',
#    u'images',
#    u'page',
#    u'loads',
#    u'quickly',
#    u'thing',
#    u'slows'),
#   3),
#  ((u'simple',
#    u'layout',
#    u'would',
#    u'appeal',
#    u'someone',
#    u'did',
#    u"n't",
#    u'technical'),
#   3),
#  ((u'left',
#    u'excellent',
#    u'one',
#    u'thing',
#    u'navigation',
#    u'alternative',
#    u'form',
#    u'getting'),
#   3),
#  ((u'respect',
#    u'offices',
#    u'hearted',
#    u'minutes',
#    u'effects',
#    u'written',
#    u'parties',
#    u'winding'),
#   3),
#  ((u'light',
#    u'warm',
#    u'shade',
#    u'make',
#    u'shadow',
#    u'different',
#    u'softer',
#    u'color'),
#   3),
#  ((u'idea',
#    u'pages',
#    u'soft',
#    u'warm',
#    u'colors',
#    u'minimum',
#    u'text',
#    u'main'),
#   3),
#  ((u'friendship',
#    u'boisterous',
#    u'continual',
#    u'delighted',
#    u'elsewhere',
#    u'convinced',
#    u'unfeeling',
#    u'introduced'),
#   3),
#  ((u'site',
#    u'found',
#    u'typos',
#    u'except',
#    u'missing',
#    u'period',
#    u'end',
#    u'text'),
#   3),
#  ((u'way',
#    u'admiration',
#    u'son',
#    u'design',
#    u'edward',
#    u'regret',
#    u'met',
#    u'lovers'),
#   3),
#  ((u'main', u'page', u'great', u';', u'big', u'chunk', u'text', u'main'), 3),
#  ((u'extremely',
#    u'fast',
#    u'graphics',
#    u'small',
#    u'welcome',
#    u'logo',
#    u'link',
#    u'buttons'),
#   3),
#  ((u'comfortable',
#    u'graphics',
#    u'kept',
#    u'minimum',
#    u'good',
#    u'load-time',
#    u'cut',
#    u'significantly'),
#   3),
#  ((u'overall',
#    u'design',
#    u'headings',
#    u'page',
#    u'think',
#    u'image',
#    u'put',
#    u'place'),
#   3),
#  ((u'page',
#    u'lots',
#    u'heart',
#    u'love',
#    u'warm',
#    u'feel',
#    u'beautiful',
#    u'work'),
#   3),
#  ((u'us',
#    u'page',
#    u'font',
#    u'arial/helvetica',
#    u'load',
#    u'time',
#    u'fast',
#    u'know'),
#   3),
#  ((u'amount',
#    u'front',
#    u'page',
#    u'!',
#    u'try',
#    u'cutting',
#    u'lot',
#    u'information'),
#   3),
#  ((u'afraid',
#    u'could',
#    u'merit',
#    u'keeps',
#    u'child',
#    u'dried',
#    u'maids',
#    u'linen'),
#   3),
#  ((u'graphics',
#    u'kept',
#    u'minimum',
#    u'great',
#    u'load',
#    u'time',
#    u'cut',
#    u'graphics'),
#   3),
#  ((u'regret',
#    u'simple',
#    u'longer',
#    u'little',
#    u'sister',
#    u'danger',
#    u'adieus',
#    u'ladies'),
#   3),
#  ((u'returned',
#    u'feelings',
#    u'may',
#    u'day',
#    u'evening',
#    u'way',
#    u'luckily',
#    u'son'),
#   3),
#  ((u'calm', u'new', u'fail', u'letter', u'wooded', u'direct', u'two', u'men'),
#   3),
#  ((u'navigate',
#    u'site',
#    u'links',
#    u'right',
#    u'left',
#    u'hand',
#    u'side',
#    u'people'),
#   3),
#  ((u'try',
#    u'using',
#    u'bold',
#    u'pink/purple',
#    u'color',
#    u'links',
#    u'perhaps',
#    u'make'),
#   3),
#  ((u'person',
#    u'layout',
#    u'simple',
#    u'effective',
#    u'clean',
#    u'site',
#    u'flawless',
#    u'look'),
#   3),
#  ((u'arranging',
#    u'set',
#    u'arranging',
#    u'dejection',
#    u'september',
#    u'happiness',
#    u'understood',
#    u'instrument'),
#   3),
#  ((u'navigation',
#    u'alternative',
#    u'form',
#    u'getting',
#    u'around',
#    u'someone',
#    u'browser',
#    u'does'),
#   3),
#  ((u'flow',
#    u'site',
#    u'black',
#    u'shadow',
#    u'nice',
#    u'idea',
#    u'try',
#    u'something'),
#   3),
#  ((u'page',
#    u'links',
#    u'right',
#    u'top',
#    u'contact',
#    u'information',
#    u'top',
#    u'main'),
#   3),
#  ((u'son',
#    u'design',
#    u'edward',
#    u'regret',
#    u'met',
#    u'lovers',
#    u'calm',
#    u'case'),
#   3),
#  ((u'making',
#    u'excellent',
#    u'one-',
#    u'tell',
#    u'worked',
#    u'polished',
#    u'creator',
#    u'satisfied'),
#   3),
#  ((u'together',
#    u'nicely',
#    u'detract',
#    u'yet',
#    u'delight',
#    u'written',
#    u'farther',
#    u'general'),
#   3),
#  ((u'anyone',
#    u'technical',
#    u'background',
#    u'simple',
#    u'effective',
#    u'washed-out',
#    u'image',
#    u'tiled'),
#   3),
#  ((u"''",
#    u'icon',
#    u'navigation',
#    u'bar',
#    u'every',
#    u'site',
#    u'way',
#    u'reader'),
#   3),
#  ((u'page',
#    u'sub',
#    u'pages',
#    u'overall',
#    u'great',
#    u'site',
#    u'great',
#    u'design'),
#   3),
#  ((u'admiration',
#    u'son',
#    u'design',
#    u'edward',
#    u'regret',
#    u'met',
#    u'lovers',
#    u'calm'),
#   3),
#  ((u'arrived',
#    u'chamber',
#    u'removal',
#    u'site',
#    u'definitely',
#    u'appeals',
#    u'average',
#    u'person'),
#   3),
#  ((u'make',
#    u'button',
#    u'graphics',
#    u'colors',
#    u'great',
#    u'purples',
#    u'excellent',
#    u'choice'),
#   3),
#  ((u'set',
#    u'existence',
#    u'dashwoods',
#    u'satisfied',
#    u'mr',
#    u'commanded',
#    u'consisted',
#    u'disposing'),
#   3),
#  ((u'period',
#    u'enough',
#    u'income',
#    u'genius',
#    u'acceptance',
#    u'bed',
#    u'sympathize',
#    u'get'),
#   3),
#  ((u'instantly',
#    u'strangers',
#    u'applauded',
#    u'discourse',
#    u'separate',
#    u'entrance',
#    u'welcomed',
#    u'sensible'),
#   3),
#  ((u'hearted',
#    u'minutes',
#    u'effects',
#    u'written',
#    u'parties',
#    u'winding',
#    u'oh',
#    u'without'),
#   3),
#  ((u'everyone',
#    u'appreciates',
#    u'!',
#    u'find',
#    u'typos',
#    u'links',
#    u'checked',
#    u'worked'),
#   3),
#  ((u'earnestly',
#    u'dejection',
#    u'four',
#    u'love',
#    u'settling',
#    u'separate',
#    u'supplied',
#    u'bed'),
#   3),
#  ((u'great',
#    u'site',
#    u'great',
#    u'design',
#    u'excellent',
#    u'content',
#    u'well',
#    u'great'),
#   3),
#  ((u'page',
#    u'links',
#    u'left',
#    u'right',
#    u'bottom',
#    u'top',
#    u'said',
#    u'boxed-in'),
#   3),
#  ((u'links',
#    u'right',
#    u'left',
#    u'hand',
#    u'side',
#    u'people',
#    u'without',
#    u'image-loading'),
#   3),
#  ((u'clean',
#    u'looking',
#    u'feel',
#    u'good',
#    u'hands',
#    u'know',
#    u'able',
#    u'find'),
#   3),
#  ((u'gay',
#    u'ham',
#    u'sigh',
#    u'find',
#    u'rent',
#    u'dispatched',
#    u'entreaties',
#    u'boisterous'),
#   3),
#  ((u'top',
#    u'said',
#    u'boxed-in',
#    u'thing',
#    u'good',
#    u'bit',
#    u'much',
#    u'confusing'),
#   3),
#  ((u'site',
#    u'would',
#    u'appeal',
#    u'anyone',
#    u'technical',
#    u'background',
#    u'simple',
#    u'effective'),
#   3),
#  ((u'dashwoods',
#    u'satisfied',
#    u'mr',
#    u'commanded',
#    u'consisted',
#    u'disposing',
#    u'engrossed',
#    u'tall'),
#   3),
#  ((u'yet',
#    u'preserved',
#    u'convinced',
#    u'coming',
#    u'regret',
#    u'simple',
#    u'longer',
#    u'little'),
#   3),
#  ((u'pianoforte',
#    u'smallest',
#    u'directly',
#    u'families',
#    u'surprise',
#    u'honoured',
#    u'speaking',
#    u'replying'),
#   3),
#  ((u'right',
#    u'middle',
#    u'screen',
#    u'obvious',
#    u'important',
#    u'information',
#    u'accessed',
#    u'reader'),
#   3),
#  ((u'immediate',
#    u'sweetness',
#    u'earnestly',
#    u'dejection',
#    u'four',
#    u'love',
#    u'settling',
#    u'separate'),
#   3),
#  ((u'fanny',
#    u'charm',
#    u'difficulty',
#    u'invitation',
#    u'put',
#    u'introduced',
#    u'see',
#    u'middletons'),
#   3),
#  ((u'can',
#    u'not',
#    u'compare',
#    u'views',
#    u'site',
#    u'internet',
#    u'explorer',
#    u'sorry'),
#   3),
#  ((u'page',
#    u'quite',
#    u'fast',
#    u'even',
#    u'moving',
#    u'link',
#    u'buttons',
#    u'find'),
#   3),
#  ((u'written',
#    u'tell',
#    u'lot',
#    u'heart',
#    u'gone',
#    u'creation',
#    u'site',
#    u'design'),
#   3),
#  ((u'create',
#    u'comforting',
#    u'feeling',
#    u'reader',
#    u'plus',
#    u'simple',
#    u'much',
#    u'text'),
#   3),
#  ((u'and',
#    u'peer',
#    u'threatment',
#    u'advocacy',
#    u"''",
#    u'remove',
#    u'h',
#    u"'treatment"),
#   3),
#  ((u'beautiful',
#    u'work',
#    u'!',
#    u'touch',
#    u'ups',
#    u'minor',
#    u'effect',
#    u'average'),
#   3),
#  ((u'tall', u'snug', u'till', u'easy', u'form', u'calm', u'new', u'fail'), 3),
#  ((u'certain',
#    u'forbade',
#    u'picture',
#    u'prevent',
#    u'carried',
#    u'get',
#    u'see',
#    u'sitting'),
#   3),
#  ((u'way',
#    u'possible',
#    u'people',
#    u'technical',
#    u'back',
#    u'ground',
#    u'would',
#    u'definitely'),
#   3),
#  ((u'navigation',
#    u'color',
#    u'links',
#    u'makes',
#    u'stand',
#    u'lot',
#    u'rest',
#    u'text'),
#   3),
#  ((u'text',
#    u'main',
#    u'page',
#    u'hyperlinks',
#    u'working',
#    u'fine',
#    u'meta',
#    u'tags'),
#   3),
#  ((u'appeal',
#    u'average',
#    u'person',
#    u'way',
#    u'simply',
#    u'done',
#    u'everything',
#    u'easy'),
#   3),
#  ((u'agreement',
#    u'found',
#    u'world',
#    u'chief',
#    u'means',
#    u'weeks',
#    u'smile',
#    u'design'),
#   3),
#  ((u'fail',
#    u'letter',
#    u'wooded',
#    u'direct',
#    u'two',
#    u'men',
#    u'indeed',
#    u'income'),
#   3),
#  ((u'checked', u'worked', u'fine', u'great', u'job', u'!', u'meta', u'tags'),
#   3),
#  ((u'layout',
#    u'makes',
#    u'anyone',
#    u'feel',
#    u'comfortable',
#    u'well',
#    u'done',
#    u'clean'),
#   3),
#  ((u'time',
#    u'page',
#    u'quite',
#    u'fast',
#    u'even',
#    u'moving',
#    u'link',
#    u'buttons'),
#   3),
#  ((u'design',
#    u'classic-',
#    u'like',
#    u'said',
#    u'bit',
#    u'bland',
#    u'think',
#    u'adding'),
#   3),
#  ((u'color',
#    u'banner/logo',
#    u'top',
#    u'kind',
#    u'merges',
#    u'rest',
#    u'page-',
#    u'make'),
#   3),
#  ((u'find',
#    u'rent',
#    u'dispatched',
#    u'entreaties',
#    u'boisterous',
#    u'say',
#    u'stimulated',
#    u'certain'),
#   3),
#  ((u'average',
#    u'person',
#    u'layout',
#    u'simple',
#    u'effective',
#    u'clean',
#    u'site',
#    u'flawless'),
#   3),
#  ((u'boxed-in',
#    u'layout',
#    u'makes',
#    u'feel',
#    u'comfortable',
#    u'graphics',
#    u'kept',
#    u'minimum'),
#   3),
#  ((u'way',
#    u'simply',
#    u'done',
#    u'everything',
#    u'easy',
#    u'find',
#    u'messing',
#    u'around'),
#   3),
#  ((u'bar',
#    u'every',
#    u'site',
#    u'way',
#    u'reader',
#    u'knows',
#    u'exactly',
#    u'up-to-date'),
#   3),
#  ((u'review',
#    u'sahara',
#    u'wwwcharityfocusorg/host/sahara',
#    u'site',
#    u"'s",
#    u'simple',
#    u'layout',
#    u'would'),
#   3),
#  ((u'getting',
#    u'around',
#    u'someone',
#    u'browser',
#    u'does',
#    u"n't",
#    u'load',
#    u'graphics'),
#   3),
#  ((u'animate',
#    u'site',
#    u'logo',
#    u'!',
#    u'extremely',
#    u'easy',
#    u'navigate',
#    u'site'),
#   3),
#  ((u'site',
#    u'content',
#    u'flows',
#    u'well',
#    u'everything',
#    u'appropriate',
#    u'place',
#    u'easy'),
#   3),
#  ((u'oh', u'eldest', u'gone', u'pure', u'late', u'gay', u'ham', u'sigh'), 3),
#  ((u'miss',
#    u'use',
#    u'easy',
#    u'celebrated',
#    u'delightful',
#    u'especially',
#    u'increasing',
#    u'instrument'),
#   3),
#  ((u'links', u'checked', u'worked', u'fine', u'great', u'job', u'!', u'meta'),
#   3),
#  ((u'page', u'links', u'left', u'hand', u'side', u'rest', u'pages', u'try'),
#   3),
#  ((u'rest', u'text', u'great-', u'easy', u'see', u'suggest', u'make', u'link'),
#   3),
#  ((u'explore',
#    u'newly',
#    u'updated',
#    u'thing',
#    u'icons',
#    u'keep',
#    u'updating',
#    u'regularly'),
#   3),
#  ((u'left',
#    u'thing',
#    u'could',
#    u'changed',
#    u'links',
#    u'size',
#    u'color',
#    u'small'),
#   3),
#  ((u'bottom',
#    u'top',
#    u'said',
#    u'boxed-in',
#    u'thing',
#    u'good',
#    u'bit',
#    u'much'),
#   3),
#  ((u'see',
#    u'sitting',
#    u'twenty',
#    u'limits',
#    u'months',
#    u'inhabit',
#    u'perhaps',
#    u'certain'),
#   3),
#  ((u'wholeness',
#    u'site',
#    u'loads',
#    u'quite',
#    u'quickly',
#    u'great',
#    u'find',
#    u'typos'),
#   3),
#  ((u'hyperlinks',
#    u'found',
#    u'work',
#    u'well',
#    u'meta',
#    u'tags',
#    u'really',
#    u'need'),
#   3),
#  ((u'definitely',
#    u'appreciate',
#    u'simplicity',
#    u'ease',
#    u'navigation',
#    u'site',
#    u'layout',
#    u'clean'),
#   3),
#  ((u'load', u'time', u'always', u"'great", u'site', u'factor', u"'", u'read'),
#   3),
#  ((u'man',
#    u'sitting',
#    u'hearted',
#    u'without',
#    u'easy',
#    u'navigate',
#    u'site',
#    u'links'),
#   3),
#  ((u'old',
#    u'sentiments',
#    u'resolution',
#    u'admiration',
#    u'unaffected',
#    u'mrs',
#    u'literature',
#    u'behaviour'),
#   3),
#  ((u'great',
#    u'load',
#    u'time',
#    u'cut',
#    u'graphics',
#    u'significant',
#    u'effective',
#    u'easy'),
#   3),
#  ((u'written',
#    u'great',
#    u'actually',
#    u'feels',
#    u'writer',
#    u'talking',
#    u'friendly',
#    u'way'),
#   3),
#  ((u'like',
#    u'making',
#    u'text',
#    u'buttons',
#    u'light',
#    u'warm',
#    u'shade',
#    u'make'),
#   3),
#  ((u'page',
#    u'also',
#    u'comforts',
#    u'reader',
#    u'way',
#    u'written',
#    u'great',
#    u'actually'),
#   3),
#  ((u'want',
#    u'keep',
#    u'good',
#    u'reputation',
#    u'!',
#    u'easy',
#    u'navigate',
#    u'links'),
#   3),
#  ((u'simple',
#    u'point',
#    u'right',
#    u'amount',
#    u'graphics',
#    u'site',
#    u'great',
#    u'way'),
#   3),
#  ((u'colors', u'minimum', u'text', u'main', u'page', u'great', u';', u'big'),
#   3),
#  ((u'present',
#    u'pages',
#    u'checked',
#    u'since',
#    u'netscape',
#    u'computer',
#    u'can',
#    u'not'),
#   3),
#  ((u'someone',
#    u'technical',
#    u'background',
#    u'easily',
#    u'see',
#    u'layout',
#    u'makes',
#    u'feel'),
#   3),
#  ((u'site',
#    u'find',
#    u'spelling',
#    u'typing',
#    u'errors',
#    u'except',
#    u'one',
#    u'main'),
#   3),
#  ((u'site',
#    u'layout',
#    u'clean',
#    u'also',
#    u'kind',
#    u'bland',
#    u'makes',
#    u'feel'),
#   3),
#  ((u'welcoming',
#    u'would',
#    u'appeal',
#    u'anyone',
#    u'layout',
#    u'nice-',
#    u'especially',
#    u'like'),
#   3),
#  ((u'hyperlinks',
#    u'working',
#    u'fine',
#    u'meta',
#    u'tags',
#    u'needs',
#    u'fixed',
#    u'main'),
#   3),
#  ((u'needs',
#    u'worked',
#    u'bit',
#    u'design',
#    u'classic-',
#    u'like',
#    u'said',
#    u'bit'),
#   3),
#  ((u'want',
#    u'design',
#    u'fitting',
#    u'sites',
#    u'purpose',
#    u'mentioned',
#    u'boxed-in',
#    u'layout'),
#   3),
#  ((u'latter',
#    u'remark',
#    u'hunted',
#    u'enough',
#    u'vulgar',
#    u'say',
#    u'man',
#    u'sitting'),
#   3),
#  ((u'appreciates',
#    u'!',
#    u'find',
#    u'typos',
#    u'links',
#    u'checked',
#    u'worked',
#    u'fine'),
#   3),
#  ((u'speaking',
#    u'replying',
#    u'mistress',
#    u'numerous',
#    u'returned',
#    u'feelings',
#    u'may',
#    u'day'),
#   3),
#  ((u'site',
#    u'loads',
#    u'quite',
#    u'quickly',
#    u'great',
#    u'find',
#    u'typos',
#    u'spelling'),
#   3),
#  ((u'done',
#    u'!',
#    u'web',
#    u'site',
#    u'review',
#    u'sahara',
#    u'wwwcharityfocusorg/host/sahara',
#    u'site'),
#   3),
#  ((u'done',
#    u'everything',
#    u'easy',
#    u'find',
#    u'messing',
#    u'around',
#    u'information',
#    u'want'),
#   3),
#  ((u'page',
#    u'find',
#    u'looking',
#    u'sitemap',
#    u'excellent',
#    u'idea',
#    u'site',
#    u'suggest'),
#   3),
#  ((u'invitation',
#    u'put',
#    u'introduced',
#    u'see',
#    u'middletons',
#    u'preference',
#    u'terminated',
#    u'excellence'),
#   3),
#  ((u'instrument',
#    u'indulgence',
#    u'contrasted',
#    u'sufficient',
#    u'unpleasant',
#    u'insensible',
#    u'favourable',
#    u'latter'),
#   3),
#  ((u'site',
#    u'loads',
#    u'extremely',
#    u'fast',
#    u'graphics',
#    u'small',
#    u'welcome',
#    u'logo'),
#   3),
#  ((u'buttons',
#    u'fast',
#    u'load',
#    u'time',
#    u'always',
#    u"'great",
#    u'site',
#    u'factor'),
#   3),
#  ((u'left',
#    u'hand',
#    u'side',
#    u'people',
#    u'without',
#    u'image-loading',
#    u'browsers',
#    u'access'),
#   3),
#  ((u'merry', u'forth', u'least', u'ye', u'stood', u'cold', u'sons', u'yet'),
#   3),
#  ((u'//cf1netmegscom/birthnet/',
#    u'site',
#    u'would',
#    u'appeal',
#    u'anyone',
#    u'technical',
#    u'background',
#    u'simple'),
#   3),
#  ((u'effect',
#    u'average',
#    u'persons',
#    u'experience',
#    u'oh',
#    u'one',
#    u'thing',
#    u'seems'),
#   3),
#  ((u'links',
#    u'arranged',
#    u'appropriately',
#    u'left',
#    u'thing',
#    u'could',
#    u'changed',
#    u'links'),
#   3),
#  ((u'gone', u'pure', u'late', u'gay', u'ham', u'sigh', u'find', u'rent'), 3),
#  ((u'possible',
#    u'people',
#    u'technical',
#    u'back',
#    u'ground',
#    u'would',
#    u'definitely',
#    u'appreciate'),
#   3),
#  ((u'rose', u'lose', u'good', u'feel', u'make', u'two', u'real', u'miss'), 3),
#  ((u'party',
#    u'worth',
#    u'weeks',
#    u'saw',
#    u'marianne',
#    u'graceful',
#    u'dissuade',
#    u'new'),
#   3),
#  ((u'chief',
#    u'means',
#    u'weeks',
#    u'smile',
#    u'design',
#    u'professional',
#    u'well',
#    u'done'),
#   3),
#  ((u'``', u'and', u'peer', u'threatment', u'advocacy', u"''", u'remove', u'h'),
#   3),
#  ((u'written',
#    u'information',
#    u'!',
#    u'sufficient',
#    u'meta',
#    u'tags',
#    u'pages',
#    u'charityfocus'),
#   3),
#  ((u'find',
#    u'typos',
#    u'spelling',
#    u'mistakes',
#    u'within',
#    u'pages',
#    u'checked',
#    u'hyperlinks'),
#   3),
#  ((u'right',
#    u'amount',
#    u'graphics',
#    u'site',
#    u'great',
#    u'way',
#    u'``',
#    u'last'),
#   3),
#  ((u'text',
#    u'main',
#    u'page',
#    u'always',
#    u'freaks',
#    u'reader',
#    u'want',
#    u'design'),
#   3),
#  ((u'everything',
#    u'easy',
#    u'find',
#    u'messing',
#    u'around',
#    u'information',
#    u'want',
#    u'convey'),
#   3),
#  ((u'reader',
#    u'knows',
#    u'exactly',
#    u'up-to-date',
#    u'information',
#    u'want',
#    u'explore',
#    u'newly'),
#   3),
#  ((u'end',
#    u'text',
#    u'main',
#    u'page',
#    u'hyperlinks',
#    u'working',
#    u'fine',
#    u'meta'),
#   3),
#  ((u'stimulated',
#    u'attachment',
#    u'projection',
#    u'loud',
#    u'lady',
#    u'mile',
#    u'sold',
#    u'four'),
#   3),
#  ((u'blushes',
#    u'respect',
#    u'offices',
#    u'hearted',
#    u'minutes',
#    u'effects',
#    u'written',
#    u'parties'),
#   3),
#  ((u'going',
#    u'top',
#    u'screen',
#    u'matter',
#    u'consistency',
#    u'links',
#    u'really',
#    u'adds'),
#   3),
#  ((u'comforts',
#    u'reader',
#    u'way',
#    u'written',
#    u'great',
#    u'actually',
#    u'feels',
#    u'writer'),
#   3),
#  ((u'goes',
#    u'together',
#    u'well',
#    u'contents',
#    u'pages',
#    u'flows',
#    u'nicely',
#    u'well'),
#   3),
#  ((u'except',
#    u'changes',
#    u'fonts-',
#    u'main',
#    u'page',
#    u'font',
#    u'middle',
#    u'section'),
#   3),
#  ((u'mouse-over',
#    u'idea',
#    u'links',
#    u'left',
#    u'hand',
#    u'side',
#    u'good',
#    u'except'),
#   3),
#  ((u'followed',
#    u'uneasy',
#    u'settle',
#    u'whence',
#    u'nature',
#    u'narrow',
#    u'afraid',
#    u'could'),
#   3),
#  ((u'bar',
#    u'perhaps',
#    u'main',
#    u'colors',
#    u'perfect',
#    u'warm',
#    u'inviting',
#    u'contents'),
#   3),
#  ((u'!',
#    u'design',
#    u'consistent-',
#    u'simple',
#    u'yellow',
#    u'green',
#    u'black',
#    u'used'),
#   3),
#  ((u'feel',
#    u'beautiful',
#    u'work',
#    u'!',
#    u'touch',
#    u'ups',
#    u'minor',
#    u'effect'),
#   3),
#  ((u'residence',
#    u'gentleman',
#    u'yet',
#    u'preserved',
#    u'convinced',
#    u'coming',
#    u'regret',
#    u'simple'),
#   3),
#  ((u'load',
#    u'time',
#    u'cut',
#    u'graphics',
#    u'significant',
#    u'effective',
#    u'easy',
#    u'navigate'),
#   3),
#  ((u'working',
#    u'fine',
#    u'meta',
#    u'tags',
#    u'needs',
#    u'fixed',
#    u'main',
#    u'page'),
#   3),
#  ((u'contact',
#    u'information',
#    u'top',
#    u'main',
#    u'page',
#    u'handy',
#    u'useful',
#    u'also'),
#   3),
#  ((u'load',
#    u'time',
#    u'animated',
#    u'title',
#    u'would',
#    u'leave',
#    u'way',
#    u'really'),
#   3),
#  ((u'merges',
#    u'rest',
#    u'page-',
#    u'make',
#    u'stand',
#    u'design',
#    u'consistent',
#    u'throughout'),
#   3),
#  ((u'presented',
#    u'simplest',
#    u'way',
#    u'possible',
#    u'people',
#    u'technical',
#    u'back',
#    u'ground'),
#   3),
#  ((u'easy',
#    u'find',
#    u'messing',
#    u'around',
#    u'information',
#    u'want',
#    u'convey',
#    u'presented'),
#   3),
#  ((u'great', u'job', u'!', u'meta', u'tags', u'present', u'pages', u'checked'),
#   3),
#  ((u'dissimilar',
#    u'way',
#    u'admiration',
#    u'son',
#    u'design',
#    u'edward',
#    u'regret',
#    u'met'),
#   3),
#  ((u'distance',
#    u'use',
#    u'nay',
#    u'lively',
#    u'people',
#    u'basket',
#    u'ladies',
#    u'window'),
#   3),
#  ((u'sympathize',
#    u'get',
#    u'dissimilar',
#    u'way',
#    u'admiration',
#    u'son',
#    u'design',
#    u'edward'),
#   3),
#  ((u'gentleman',
#    u'yet',
#    u'preserved',
#    u'convinced',
#    u'coming',
#    u'regret',
#    u'simple',
#    u'longer'),
#   3),
#  ((u'meta',
#    u'tags',
#    u'really',
#    u'need',
#    u'added',
#    u'technical',
#    u'branding',
#    u'done'),
#   3),
#  ((u';', u'big', u'chunk', u'text', u'main', u'page', u'always', u'freaks'),
#   3),
#  ((u'child',
#    u'dried',
#    u'maids',
#    u'linen',
#    u'two',
#    u'color',
#    u'scheme',
#    u'good'),
#   3),
#  ((u'show',
#    u'also',
#    u'liven',
#    u'site',
#    u'content',
#    u'flows',
#    u'well',
#    u'everything'),
#   3),
#  ((u'threatment',
#    u'advocacy',
#    u"''",
#    u'remove',
#    u'h',
#    u"'treatment",
#    u"'",
#    u'checked'),
#   3),
#  ((u'concluded',
#    u'resembled',
#    u'suspected',
#    u'resources',
#    u'curiosity',
#    u'joy',
#    u'led',
#    u'cottage'),
#   3),
#  ((u'gone',
#    u'site',
#    u'design',
#    u'mostly',
#    u'consistent',
#    u'except',
#    u'changes',
#    u'fonts-'),
#   3),
#  ((u'change',
#    u'fonts',
#    u'arial',
#    u'rounded',
#    u'font',
#    u'go',
#    u'professional',
#    u'feel'),
#   3),
#  ((u'right',
#    u'top',
#    u'contact',
#    u'information',
#    u'top',
#    u'main',
#    u'page',
#    u'handy'),
#   3),
#  ((u'text',
#    u'bottom',
#    u'handy',
#    u'essential',
#    u'good',
#    u'site',
#    u'good',
#    u'idea'),
#   3),
#  ((u'navigation',
#    u'perfect',
#    u'!',
#    u'color',
#    u'scheme',
#    u'effective',
#    u'used',
#    u'around'),
#   3),
#  ((u'linen', u'two', u'color', u'scheme', u'good', u'try', u'adding', u'one'),
#   3),
#  ((u'worth',
#    u'weeks',
#    u'saw',
#    u'marianne',
#    u'graceful',
#    u'dissuade',
#    u'new',
#    u'outlived'),
#   3),
#  ((u'logo',
#    u'present',
#    u'web',
#    u'site',
#    u'review',
#    u'cal-pep',
#    u'wwwcharityfocusorg/host/calpep/',
#    u'site'),
#   3),
#  ((u'west', u'felt', u'say', u'noise', u'taste', u'merry', u'plate', u'share'),
#   3),
#  ((u'lot', u'rest', u'text', u'great-', u'easy', u'see', u'suggest', u'make'),
#   3),
#  ((u'average',
#    u'person',
#    u'way',
#    u'simply',
#    u'done',
#    u'everything',
#    u'easy',
#    u'find'),
#   3),
#  ((u"'s",
#    u'simple',
#    u'layout',
#    u'would',
#    u'appeal',
#    u'someone',
#    u'did',
#    u"n't"),
#   3),
#  ((u'effective',
#    u'used',
#    u'around',
#    u'site',
#    u'show',
#    u'also',
#    u'liven',
#    u'site'),
#   3),
#  ((u'go',
#    u'another',
#    u'page',
#    u'layout',
#    u'makes',
#    u'feel',
#    u'comfortable',
#    u'site'),
#   3),
#  ((u'title',
#    u'liven',
#    u'pages',
#    u'bit',
#    u'small',
#    u'amount',
#    u'images',
#    u'page'),
#   3),
#  ((u'invitation',
#    u'dried',
#    u'quick',
#    u'round',
#    u'order',
#    u'add',
#    u'past',
#    u'see'),
#   3),
#  ((u'fine',
#    u'meta',
#    u'tags',
#    u'present',
#    u'technical',
#    u'branding',
#    u'main',
#    u'page'),
#   3),
#  ((u'also',
#    u'comforts',
#    u'reader',
#    u'way',
#    u'written',
#    u'great',
#    u'actually',
#    u'feels'),
#   3),
#  ((u'dispatched',
#    u'entreaties',
#    u'boisterous',
#    u'say',
#    u'stimulated',
#    u'certain',
#    u'forbade',
#    u'picture'),
#   3),
#  ((u'page',
#    u'linked',
#    u'charityfocus',
#    u'text',
#    u'cf',
#    u'logo',
#    u'present',
#    u'excellent'),
#   3),
#  ((u'comforting',
#    u'feeling',
#    u'reader',
#    u'plus',
#    u'simple',
#    u'much',
#    u'text',
#    u'first'),
#   3),
#  ((u'web',
#    u'site',
#    u'review',
#    u'charityfocus',
#    u'site',
#    u'wwwcharityfocusorg',
#    u'site',
#    u'would'),
#   3),
#  ((u'nature',
#    u'narrow',
#    u'afraid',
#    u'could',
#    u'merit',
#    u'keeps',
#    u'child',
#    u'dried'),
#   3),
#  ((u'sites',
#    u'purpose',
#    u'mentioned',
#    u'boxed-in',
#    u'layout',
#    u'makes',
#    u'feel',
#    u'comfortable'),
#   3),
#  ((u'dine', u'oh', u'knew', u'even', u'boy', u'along', u'far', u'equal'), 3),
#  ((u'excellent-',
#    u'simple',
#    u'point',
#    u'right',
#    u'amount',
#    u'graphics',
#    u'site',
#    u'great'),
#   3),
#  ((u'stood',
#    u'cold',
#    u'sons',
#    u'yet',
#    u'delivered',
#    u'middleton',
#    u'therefore',
#    u'attachment'),
#   3),
#  ((u'amount',
#    u'graphics',
#    u'site',
#    u'great',
#    u'way',
#    u'``',
#    u'last',
#    u'updated'),
#   3),
#  ((u'set',
#    u'arranging',
#    u'dejection',
#    u'september',
#    u'happiness',
#    u'understood',
#    u'instrument',
#    u'connection'),
#   3),
#  ((u'one',
#    u'day',
#    u'perceived',
#    u'old',
#    u'blushes',
#    u'respect',
#    u'offices',
#    u'hearted'),
#   3),
#  ((u'great',
#    u'actually',
#    u'feels',
#    u'writer',
#    u'talking',
#    u'friendly',
#    u'way',
#    u'design'),
#   3),
#  ((u'delightful',
#    u'especially',
#    u'increasing',
#    u'instrument',
#    u'indulgence',
#    u'contrasted',
#    u'sufficient',
#    u'unpleasant'),
#   3),
#  ((u'fast-loading',
#    u'colors',
#    u'images',
#    u'go',
#    u'together',
#    u'nicely',
#    u'detract',
#    u'yet'),
#   3),
#  ((u'links',
#    u'left',
#    u'right',
#    u'bottom',
#    u'top',
#    u'said',
#    u'boxed-in',
#    u'thing'),
#   3),
#  ((u'laughing',
#    u'one',
#    u'moderate',
#    u'shy',
#    u'seeing',
#    u'piqued',
#    u'garden',
#    u'merry'),
#   3),
#  ((u"'ve", u'seen', u'animated', u'logo', u'great', u'adds', u'life', u'site'),
#   3),
#  ((u'words', u'style', u'``', u'sahara', u"''", u'title', u'liven', u'pages'),
#   3),
#  ((u'need', u'miss', u'four', u'case', u'fine', u'age', u'tell', u'families'),
#   3),
#  ((u'believed',
#    u'distance',
#    u'use',
#    u'nay',
#    u'lively',
#    u'people',
#    u'basket',
#    u'ladies'),
#   3),
#  ((u'sweetness',
#    u'earnestly',
#    u'dejection',
#    u'four',
#    u'love',
#    u'settling',
#    u'separate',
#    u'supplied'),
#   3),
#  ((u'something',
#    u'like',
#    u'making',
#    u'text',
#    u'buttons',
#    u'light',
#    u'warm',
#    u'shade'),
#   3),
#  ((u'logo',
#    u'great',
#    u'adds',
#    u'life',
#    u'site',
#    u'stops',
#    u'moving',
#    u'annoying'),
#   3),
#  ((u'admiration',
#    u'unaffected',
#    u'mrs',
#    u'literature',
#    u'behaviour',
#    u'new',
#    u'set',
#    u'existence'),
#   3),
#  ((u'site',
#    u'stops',
#    u'moving',
#    u'annoying',
#    u'least',
#    u'graphics',
#    u'kept',
#    u'minimum'),
#   3),
#  ((u'informative',
#    u'easy',
#    u'navigate',
#    u'presentation',
#    u'needs',
#    u'worked',
#    u'little',
#    u'glitches'),
#   3),
#  ((u'letter',
#    u'wooded',
#    u'direct',
#    u'two',
#    u'men',
#    u'indeed',
#    u'income',
#    u'sister'),
#   3),
#  ((u'parties',
#    u'winding',
#    u'oh',
#    u'without',
#    u'started',
#    u'residence',
#    u'gentleman',
#    u'yet'),
#   3),
#  ((u'without',
#    u'easy',
#    u'navigate',
#    u'site',
#    u'links',
#    u'right',
#    u'left',
#    u'hand'),
#   3),
#  ((u'navigate',
#    u'presentation',
#    u'needs',
#    u'worked',
#    u'little',
#    u'glitches',
#    u'well',
#    u'done'),
#   3),
#  ((u'checked',
#    u'since',
#    u'netscape',
#    u'computer',
#    u'can',
#    u'not',
#    u'compare',
#    u'views'),
#   3),
#  ((u'load-time',
#    u'cut',
#    u'significantly',
#    u'mouse-over',
#    u'idea',
#    u'links',
#    u'left',
#    u'hand'),
#   3),
#  ((u'technical',
#    u'branding',
#    u'done',
#    u'page',
#    u'directed',
#    u'charityfocus',
#    u'logo',
#    u'present'),
#   3),
#  ((u'font',
#    u'middle',
#    u'section',
#    u'times',
#    u'us',
#    u'page',
#    u'font',
#    u'arial/helvetica'),
#   3),
#  ((u'would',
#    u'appeal',
#    u'average',
#    u'person',
#    u'way',
#    u'simply',
#    u'done',
#    u'everything'),
#   3),
#  ((u'connection',
#    u'appearance',
#    u'invitation',
#    u'dried',
#    u'quick',
#    u'round',
#    u'order',
#    u'add'),
#   3),
#  ((u'font', u'size', u'face', u'throughout', u'well', u'done', u'!', u'site'),
#   3),
#  ((u'share',
#    u'resolve',
#    u'arrived',
#    u'chamber',
#    u'removal',
#    u'site',
#    u'definitely',
#    u'appeals'),
#   3),
#  ((u'consistent',
#    u'except',
#    u'changes',
#    u'fonts-',
#    u'main',
#    u'page',
#    u'font',
#    u'middle'),
#   3),
#  ((u'wooded',
#    u'direct',
#    u'two',
#    u'men',
#    u'indeed',
#    u'income',
#    u'sister',
#    u'impression'),
#   3),
#  ((u'entered',
#    u'site',
#    u'could',
#    u'tell',
#    u'lot',
#    u'thought',
#    u'gone',
#    u'making'),
#   3),
#  ((u'main',
#    u'page',
#    u'hyperlinks',
#    u'working',
#    u'fine',
#    u'meta',
#    u'tags',
#    u'present'),
#   3),
#  ((u'different',
#    u'softer',
#    u'color',
#    u'site',
#    u'mostly',
#    u'easy',
#    u'navigate',
#    u'except'),
#   3),
#  ((u'also',
#    u'kind',
#    u'bland',
#    u'makes',
#    u'feel',
#    u'comfortable',
#    u'site',
#    u'do'),
#   3),
#  ((u'links',
#    u'right',
#    u'left',
#    u'excellent',
#    u'one',
#    u'thing',
#    u'navigation',
#    u'alternative'),
#   3),
#  ((u'excellent',
#    u'one',
#    u'thing',
#    u'navigation',
#    u'alternative',
#    u'form',
#    u'getting',
#    u'around'),
#   3),
#  ((u'old',
#    u'fanny',
#    u'charm',
#    u'difficulty',
#    u'invitation',
#    u'put',
#    u'introduced',
#    u'see'),
#   3),
#  ((u'newly',
#    u'updated',
#    u'thing',
#    u'icons',
#    u'keep',
#    u'updating',
#    u'regularly',
#    u'want'),
#   3),
#  ((u'done', u'easy', u'read', u'tell', u'lot', u'heart', u'gone', u'site'), 3),
#  ((u'involved',
#    u'web',
#    u'site',
#    u'review',
#    u'birth',
#    u'network',
#    u'http',
#    u':'),
#   3),
#  ((u'internet',
#    u'explorer',
#    u'sorry',
#    u'!',
#    u'overall',
#    u'excellent',
#    u'page',
#    u'lots'),
#   3),
#  ((u'written',
#    u'farther',
#    u'general',
#    u'bred',
#    u'dare',
#    u'rose',
#    u'lose',
#    u'good'),
#   3),
#  ((u"'s", u'great', u'way', u'main', u'page', u'links', u'right', u'top'), 3),
#  ((u'h',
#    u"'treatment",
#    u"'",
#    u'checked',
#    u'hyperlinks',
#    u'working',
#    u'fine',
#    u'meta'),
#   3),
#  ((u'image',
#    u'tiled',
#    u'background',
#    u'welcoming',
#    u'would',
#    u'appeal',
#    u'anyone',
# ...
#    u'size',
#    u'face',
#    u'throughout',
#    u'well'),
#   3),
#  ((u'evening',
#    u'way',
#    u'luckily',
#    u'son',
#    u'exposed',
#    u'get',
#    u'general',
#    u'greatly'),
#   3),
#  ((u'pages-', u'clean', u'easy', u'read', u'well', u'done', u'!', u'load'), 3),
#  ((u'netscape',
#    u'computer',
#    u'can',
#    u'not',
#    u'compare',
#    u'views',
#    u'site',
#    u'internet'),
#   3),
#  ((u'new',
#    u'outlived',
#    u'prospect',
#    u'followed',
#    u'uneasy',
#    u'settle',
#    u'whence',
#    u'nature'),
#   3),
#  ((u'design',
#    u'consistent',
#    u'throughout',
#    u'gives',
#    u'site',
#    u'sense',
#    u'completion',
#    u'wholeness'),
#   3),
#  ((u'make',
#    u'bold',
#    u'red',
#    u'white',
#    u'yellow',
#    u'color',
#    u'scheme',
#    u'goes'),
#   3),
#  ((u'design',
#    u'headings',
#    u'page',
#    u'think',
#    u'image',
#    u'put',
#    u'place',
#    u'words'),
#   3),
#  ((u'busy', u'dine', u'oh', u'knew', u'even', u'boy', u'along', u'far'), 3),
#  ((u'access',
#    u'links',
#    u'via',
#    u'text',
#    u'bottom',
#    u'handy',
#    u'essential',
#    u'good'),
#   3),
#  ((u'use',
#    u'nay',
#    u'lively',
#    u'people',
#    u'basket',
#    u'ladies',
#    u'window',
#    u'expect'),
#   3),
#  ((u'side',
#    u'people',
#    u'without',
#    u'image-loading',
#    u'browsers',
#    u'access',
#    u'links',
#    u'via'),
#   3),
#  ((u'factor',
#    u"'",
#    u'read',
#    u'whole',
#    u'site',
#    u'find',
#    u'spelling',
#    u'typing'),
#   3),
#  ((u'great',
#    u'work',
#    u'!',
#    u'web',
#    u'site',
#    u'review',
#    u'charityfocus',
#    u'site'),
#   3),
#  ((u'viewer',
#    u'design',
#    u'consistent',
#    u'throughout',
#    u'pages-',
#    u'clean',
#    u'easy',
#    u'read'),
#   3),
#  ((u'weeks',
#    u'smile',
#    u'design',
#    u'professional',
#    u'well',
#    u'done',
#    u'love',
#    u'washed-out'),
#   3),
#  ((u'without',
#    u'technical',
#    u'background',
#    u'would',
#    u'definitely',
#    u'appreciate',
#    u'layout',
#    u'makes'),
#   3),
#  ((u'pages',
#    u'checked',
#    u'since',
#    u'netscape',
#    u'computer',
#    u'can',
#    u'not',
#    u'compare'),
#   3),
#  ((u'boxed-in',
#    u'idea',
#    u'pages',
#    u'soft',
#    u'warm',
#    u'colors',
#    u'minimum',
#    u'text'),
#   3),
#  ((u'try',
#    u'adding',
#    u'one',
#    u'two',
#    u'colors',
#    u'orange/yellow',
#    u'blue',
#    u'go'),
#   3),
#  ((u'sold', u'four', u'need', u'miss', u'four', u'case', u'fine', u'age'), 3),
#  ((u'would',
#    u'good',
#    u'content',
#    u'flows',
#    u'well',
#    u'well',
#    u'written',
#    u'information'),
#   3),
#  ((u'navigation',
#    u'site',
#    u'layout',
#    u'clean',
#    u'also',
#    u'kind',
#    u'bland',
#    u'makes'),
#   3),
#  ((u'arranging',
#    u'dejection',
#    u'september',
#    u'happiness',
#    u'understood',
#    u'instrument',
#    u'connection',
#    u'appearance'),
#   3),
#  ((u'contents',
#    u'pages',
#    u'flows',
#    u'nicely',
#    u'well',
#    u'written',
#    u'tell',
#    u'lot'),
#   3),
#  ((u'cf',
#    u'logo',
#    u'present',
#    u'excellent',
#    u'site',
#    u'simple',
#    u'design',
#    u'informative-'),
#   3),
#  ((u'well',
#    u'done',
#    u'!',
#    u'web',
#    u'site',
#    u'review',
#    u'sahara',
#    u'wwwcharityfocusorg/host/sahara'),
#   3),
#  ((u'wwwcharityfocusorg',
#    u'site',
#    u'would',
#    u'appeal',
#    u'average',
#    u'person',
#    u'colors',
#    u'warm'),
#   3),
#  ((u'persons',
#    u'experience',
#    u'oh',
#    u'one',
#    u'thing',
#    u'seems',
#    u'like',
#    u'y2k'),
#   3),
#  ((u'genius',
#    u'acceptance',
#    u'bed',
#    u'sympathize',
#    u'get',
#    u'dissimilar',
#    u'way',
#    u'admiration'),
#   3),
#  ((u'dejection',
#    u'september',
#    u'happiness',
#    u'understood',
#    u'instrument',
#    u'connection',
#    u'appearance',
#    u'invitation'),
#   3),
#  ((u'partiality',
#    u'instantly',
#    u'immediate',
#    u'saw',
#    u'one',
#    u'day',
#    u'perceived',
#    u'old'),
#   3),
#  ((u'somewhere',
#    u'would',
#    u'good',
#    u'content',
#    u'flows',
#    u'well',
#    u'well',
#    u'written'),
#   3),
#  ((u'design',
#    u'informative-',
#    u'great',
#    u'work',
#    u'!',
#    u'web',
#    u'site',
#    u'review'),
#   3),
#  ((u'instantly',
#    u'immediate',
#    u'saw',
#    u'one',
#    u'day',
#    u'perceived',
#    u'old',
#    u'blushes'),
#   3),
#  ((u'red',
#    u'white',
#    u'yellow',
#    u'color',
#    u'scheme',
#    u'goes',
#    u'together',
#    u'well'),
#   3),
#  ((u'way',
#    u'written',
#    u'great',
#    u'actually',
#    u'feels',
#    u'writer',
#    u'talking',
#    u'friendly'),
#   3),
#  ((u'pleasant',
#    u'speaking',
#    u'bringing',
#    u'thoughts',
#    u'view',
#    u'busy',
#    u'dine',
#    u'oh'),
#   3),
#  ((u'idea',
#    u'site',
#    u'suggest',
#    u'put',
#    u'link',
#    u'obvious',
#    u'place',
#    u'like'),
#   3),
#  ((u'together',
#    u'purple',
#    u'color',
#    u'accessed',
#    u'links',
#    u'nice',
#    u'maybe',
#    u'turquoise'),
#   3),
#  ((u'checked',
#    u'hyperlinks',
#    u'working',
#    u'fine',
#    u'meta',
#    u'tags',
#    u'needs',
#    u'fixed'),
#   3),
#  ((u'thing',
#    u'navigation',
#    u'alternative',
#    u'form',
#    u'getting',
#    u'around',
#    u'someone',
#    u'browser'),
#   3),
#  ((u'colors',
#    u'warm',
#    u'inviting',
#    u'first',
#    u'entered',
#    u'site',
#    u'could',
#    u'tell'),
#   3),
#  ((u'zealously',
#    u'prevailed',
#    u'arranging',
#    u'set',
#    u'arranging',
#    u'dejection',
#    u'september',
#    u'happiness'),
#   3),
#  ((u'cal-pep',
#    u'wwwcharityfocusorg/host/calpep/',
#    u'site',
#    u'would',
#    u'appeal',
#    u'average',
#    u'person',
#    u'way'),
#   3),
#  ((u'bed',
#    u'sympathize',
#    u'get',
#    u'dissimilar',
#    u'way',
#    u'admiration',
#    u'son',
#    u'design'),
#   3),
#  ((u'pages',
#    u'flows',
#    u'nicely',
#    u'well',
#    u'written',
#    u'tell',
#    u'lot',
#    u'heart'),
#   3),
#  ((u'noise',
#    u'taste',
#    u'merry',
#    u'plate',
#    u'share',
#    u'resolve',
#    u'arrived',
#    u'chamber'),
#   3),
#  ((u'chatty',
#    u'seemed',
#    u'warmth',
#    u'nay',
#    u'add',
#    u'far',
#    u'immediate',
#    u'sweetness'),
#   3),
#  ((u'cold',
#    u'sons',
#    u'yet',
#    u'delivered',
#    u'middleton',
#    u'therefore',
#    u'attachment',
#    u'companions'),
#   3),
#  ((u'put',
#    u'introduced',
#    u'see',
#    u'middletons',
#    u'preference',
#    u'terminated',
#    u'excellence',
#    u'invitation'),
#   3),
#  ((u'job',
#    u'everyone',
#    u'involved',
#    u'web',
#    u'site',
#    u'review',
#    u'birth',
#    u'network'),
#   3),
#  ((u'adds',
#    u'site',
#    u'found',
#    u'typos',
#    u'except',
#    u'missing',
#    u'period',
#    u'end'),
#   3),
#  ((u'information',
#    u'want',
#    u'explore',
#    u'newly',
#    u'updated',
#    u'thing',
#    u'icons',
#    u'keep'),
#   3),
#  ((u'excellence',
#    u'invitation',
#    u'projection',
#    u'graceful',
#    u'shy',
#    u'believed',
#    u'distance',
#    u'use'),
#   3),
#  ((u'middle',
#    u'section',
#    u'times',
#    u'us',
#    u'page',
#    u'font',
#    u'arial/helvetica',
#    u'load'),
#   3),
#  ((u'used',
#    u'every',
#    u'page',
#    u'left',
#    u'font',
#    u'size',
#    u'face',
#    u'throughout'),
#   3),
#  ((u'better',
#    u'!',
#    u'design',
#    u'consistent-',
#    u'simple',
#    u'yellow',
#    u'green',
#    u'black'),
#   3),
#  ((u'comfortable',
#    u'well',
#    u'done',
#    u'clean',
#    u'looking',
#    u'feel',
#    u'good',
#    u'hands'),
#   3),
#  ((u'longer',
#    u'little',
#    u'sister',
#    u'danger',
#    u'adieus',
#    u'ladies',
#    u'houses',
#    u'oh'),
#   3),
#  ((u'makes',
#    u'feel',
#    u'comfortable',
#    u'especially',
#    u'boxed-in',
#    u'idea',
#    u'pages',
#    u'soft'),
#   3),
#  ((u'read', u'tell', u'lot', u'heart', u'gone', u'site', u'design', u'mostly'),
#   3),
#  ((u'changes',
#    u'fonts-',
#    u'main',
#    u'page',
#    u'font',
#    u'middle',
#    u'section',
#    u'times'),
#   3),
#  ((u'left',
#    u'behind',
#    u'links',
#    u'site',
#    u'feels',
#    u'great',
#    u'suggest',
#    u'change'),
#   3),
#  ((u'quick', u'round', u'order', u'add', u'past', u'see', u'west', u'felt'),
#   3),
#  ((u'!',
#    u'easy',
#    u'navigate',
#    u'links',
#    u'arranged',
#    u'appropriately',
#    u'left',
#    u'thing'),
#   3),
#  ((u'vulgar',
#    u'say',
#    u'man',
#    u'sitting',
#    u'hearted',
#    u'without',
#    u'easy',
#    u'navigate'),
#   3),
#  ((u'great', u'way', u'main', u'page', u'links', u'right', u'top', u'contact'),
#   3),
#  ((u'know',
#    u'links',
#    u'going',
#    u'top',
#    u'screen',
#    u'matter',
#    u'consistency',
#    u'links'),
#   3),
#  ((u'layout',
#    u'clean',
#    u'also',
#    u'kind',
#    u'bland',
#    u'makes',
#    u'feel',
#    u'comfortable'),
#   3),
#  ((u'simplicity',
#    u'ease',
#    u'navigation',
#    u'site',
#    u'layout',
#    u'clean',
#    u'also',
#    u'kind'),
#   3),
#  ((u'ground',
#    u'would',
#    u'definitely',
#    u'appreciate',
#    u'simplicity',
#    u'ease',
#    u'navigation',
#    u'site'),
#   3),
#  ((u'day',
#    u'evening',
#    u'way',
#    u'luckily',
#    u'son',
#    u'exposed',
#    u'get',
#    u'general'),
#   3),
#  ((u'buttons',
#    u'move',
#    u'light',
#    u'kind',
#    u'animation',
#    u'page',
#    u'perhaps',
#    u'could'),
#   3),
#  ((u'directed',
#    u'charityfocus',
#    u'logo',
#    u'present',
#    u'web',
#    u'site',
#    u'review',
#    u'cal-pep'),
#   3),
#  ((u'``', u'sahara', u"''", u'title', u'liven', u'pages', u'bit', u'small'),
#   3),
#  ((u'time', u'always', u"'great", u'site', u'factor', u"'", u'read', u'whole'),
#   3),
#  ((u'prevailed',
#    u'arranging',
#    u'set',
#    u'arranging',
#    u'dejection',
#    u'september',
#    u'happiness',
#    u'understood'),
#   3),
#  ((u'easily',
#    u'particular',
#    u'unaffected',
#    u'projection',
#    u'sentiments',
#    u'music',
#    u'marry',
#    u'cause'),
#   3),
#  ((u'suggest',
#    u'put',
#    u'link',
#    u'obvious',
#    u'place',
#    u'like',
#    u'navigation',
#    u'bar'),
#   3),
#  ((u'people',
#    u'without',
#    u'image-loading',
#    u'browsers',
#    u'access',
#    u'links',
#    u'via',
#    u'text'),
#   3),
#  ((u'sense',
#    u'completion',
#    u'wholeness',
#    u'site',
#    u'loads',
#    u'quite',
#    u'quickly',
#    u'great'),
#   3),
#  ((u"'",
#    u'checked',
#    u'hyperlinks',
#    u'working',
#    u'fine',
#    u'meta',
#    u'tags',
#    u'needs'),
#   3),
#  ((u'computer',
#    u'can',
#    u'not',
#    u'compare',
#    u'views',
#    u'site',
#    u'internet',
#    u'explorer'),
#   3),
#  ((u'like', u'way', u'added', u'little', u'tab', u'top', u'links', u'sit'), 3),
#  ((u'enough',
#    u'income',
#    u'genius',
#    u'acceptance',
#    u'bed',
#    u'sympathize',
#    u'get',
#    u'dissimilar'),
#   3),
#  ((u'another',
#    u'page',
#    u'layout',
#    u'makes',
#    u'feel',
#    u'comfortable',
#    u'site',
#    u'said'),
#   3),
#  ((u'warm', u'colors', u'minimum', u'text', u'main', u'page', u'great', u';'),
#   3),
#  ((u'tell',
#    u'worked',
#    u'polished',
#    u'creator',
#    u'satisfied',
#    u'someone',
#    u'technical',
#    u'background'),
#   3),
#  ((u'understood',
#    u'instrument',
#    u'connection',
#    u'appearance',
#    u'invitation',
#    u'dried',
#    u'quick',
#    u'round'),
#   3),
#  ((u'needs',
#    u'fixed',
#    u'main',
#    u'page',
#    u'linked',
#    u'charityfocus',
#    u'logo',
#    u'site'),
#   3),
#  ((u'meta',
#    u'tags',
#    u'needs',
#    u'fixed',
#    u'main',
#    u'page',
#    u'linked',
#    u'charityfocus'),
#   3),
#  ((u'section',
#    u'right',
#    u'middle',
#    u'screen',
#    u'obvious',
#    u'important',
#    u'information',
#    u'accessed'),
#   3),
#  ((u'appropriate',
#    u'place',
#    u'easy',
#    u'read-',
#    u'less',
#    u'huge',
#    u'chunks',
#    u'text'),
#   3),
#  ((u'would',
#    u'difficult',
#    u'get',
#    u'around',
#    u'site',
#    u'links',
#    u'text',
#    u'form'),
#   3),
#  ((u'big',
#    u'chunk',
#    u'text',
#    u'main',
#    u'page',
#    u'always',
#    u'freaks',
#    u'reader'),
#   3),
#  ((u'site',
#    u'wwwcharityfocusorg',
#    u'site',
#    u'would',
#    u'appeal',
#    u'average',
#    u'person',
#    u'colors'),
#   3),
#  ((u'feels',
#    u'writer',
#    u'talking',
#    u'friendly',
#    u'way',
#    u'design',
#    u'excellent-',
#    u'simple'),
#   3),
#  ((u'lot',
#    u'heart',
#    u'gone',
#    u'site',
#    u'design',
#    u'mostly',
#    u'consistent',
#    u'except'),
#   3),
#  ((u'animated',
#    u'logo',
#    u'great',
#    u'adds',
#    u'life',
#    u'site',
#    u'stops',
#    u'moving'),
#   3),
#  ((u'top',
#    u'screen',
#    u'matter',
#    u'consistency',
#    u'links',
#    u'really',
#    u'adds',
#    u'ease'),
#   3),
#  ((u'shy',
#    u'seeing',
#    u'piqued',
#    u'garden',
#    u'merry',
#    u'forth',
#    u'least',
#    u'ye'),
#   3),
#  ((u'text', u'main', u'page', u'great', u';', u'big', u'chunk', u'text'), 3),
#  ((u'main',
#    u'page',
#    u'linked',
#    u'charityfocus',
#    u'text',
#    u'cf',
#    u'logo',
#    u'present'),
#   3),
#  ((u'separate',
#    u'supplied',
#    u'bed',
#    u'concluded',
#    u'resembled',
#    u'suspected',
#    u'resources',
#    u'curiosity'),
#   3),
#  ((u'forth',
#    u'least',
#    u'ye',
#    u'stood',
#    u'cold',
#    u'sons',
#    u'yet',
#    u'delivered'),
#   3),
#  ((u'kept',
#    u'minimum',
#    u'good',
#    u'load-time',
#    u'cut',
#    u'significantly',
#    u'mouse-over',
#    u'idea'),
#   3),
#  ((u'!',
#    u'sufficient',
#    u'meta',
#    u'tags',
#    u'pages',
#    u'charityfocus',
#    u'logo',
#    u'present'),
#   3),
#  ((u'site',
#    u'links',
#    u'right',
#    u'left',
#    u'hand',
#    u'side',
#    u'people',
#    u'without'),
#   3),
#  ((u'boisterous',
#    u'continual',
#    u'delighted',
#    u'elsewhere',
#    u'convinced',
#    u'unfeeling',
#    u'introduced',
#    u'stimulated'),
#   3),
#  ((u'front',
#    u'page',
#    u'interesting',
#    u'information',
#    u'get',
#    u'viewer',
#    u'design',
#    u'consistent'),
#   3),
#  ((u'explorer',
#    u'sorry',
#    u'!',
#    u'overall',
#    u'excellent',
#    u'page',
#    u'lots',
#    u'heart'),
#   3),
#  ((u'really',
#    u'adds',
#    u'site',
#    u'found',
#    u'typos',
#    u'except',
#    u'missing',
#    u'period'),
#   3),
#  ((u'read-', u'less', u'huge', u'chunks', u'text', u'better', u'!', u'design'),
#   3),
#  ((u'entrance',
#    u'directly',
#    u'elegance',
#    u'greater',
#    u'cottage',
#    u'gay',
#    u'parties',
#    u'natural'),
#   3),
#  ((u'feet',
#    u'tell',
#    u'busy',
#    u'considered',
#    u'imprudence',
#    u'friendship',
#    u'boisterous',
#    u'continual'),
#   3),
#  ((u'met',
#    u'enabled',
#    u'attempt',
#    u'talking',
#    u'delight',
#    u'dare',
#    u'feet',
#    u'tell'),
#   3),
#  ((u'perhaps',
#    u'add',
#    u'color',
#    u'banner/logo',
#    u'top',
#    u'kind',
#    u'merges',
#    u'rest'),
#   3),
#  ((u'stand',
#    u'even',
#    u'perhaps',
#    u'make',
#    u'bold',
#    u'red',
#    u'white',
#    u'yellow'),
#   3),
#  ((u'adding',
#    u'one',
#    u'two',
#    u'colors',
#    u'orange/yellow',
#    u'blue',
#    u'go',
#    u'well'),
#   3),
#  ((u'clean',
#    u'also',
#    u'kind',
#    u'bland',
#    u'makes',
#    u'feel',
#    u'comfortable',
#    u'site'),
#   3),
#  ((u'simple',
#    u'design',
#    u'informative-',
#    u'great',
#    u'work',
#    u'!',
#    u'web',
#    u'site'),
#   3),
#  ((u'welcomed',
#    u'sensible',
#    u'laughing',
#    u'one',
#    u'moderate',
#    u'shy',
#    u'seeing',
#    u'piqued'),
#   3),
#  ((u'great',
#    u'purples',
#    u'excellent',
#    u'choice',
#    u'site',
#    u'perhaps',
#    u'add',
#    u'color'),
#   3),
#  ((u'maids',
#    u'linen',
#    u'two',
#    u'color',
#    u'scheme',
#    u'good',
#    u'try',
#    u'adding'),
#   3),
#  ((u'page', u'font', u'middle', u'section', u'times', u'us', u'page', u'font'),
#   3),
#  ((u'scheme',
#    u'effective',
#    u'used',
#    u'around',
#    u'site',
#    u'show',
#    u'also',
#    u'liven'),
#   3),
#  ((u'thought',
#    u'gone',
#    u'making',
#    u'excellent',
#    u'one-',
#    u'tell',
#    u'worked',
#    u'polished'),
#   3),
#  ((u'shadow',
#    u'nice',
#    u'idea',
#    u'try',
#    u'something',
#    u'like',
#    u'making',
#    u'text'),
#   3),
#  ((u'new',
#    u'fail',
#    u'letter',
#    u'wooded',
#    u'direct',
#    u'two',
#    u'men',
#    u'indeed'),
#   3),
#  ((u'views',
#    u'site',
#    u'internet',
#    u'explorer',
#    u'sorry',
#    u'!',
#    u'overall',
#    u'excellent'),
#   3),
#  ((u'men',
#    u'indeed',
#    u'income',
#    u'sister',
#    u'impression',
#    u'admiration',
#    u'partiality',
#    u'instantly'),
#   3),
#  ((u'everyone',
#    u'involved',
#    u'web',
#    u'site',
#    u'review',
#    u'birth',
#    u'network',
#    u'http'),
#   3),
#  ((u'see', u'west', u'felt', u'say', u'noise', u'taste', u'merry', u'plate'),
#   3),
#  ((u'site',
#    u'way',
#    u'reader',
#    u'knows',
#    u'exactly',
#    u'up-to-date',
#    u'information',
#    u'want'),
#   3),
#  ((u'done',
#    u'clean',
#    u'looking',
#    u'feel',
#    u'good',
#    u'hands',
#    u'know',
#    u'able'),
#   3),
#  ((u'present',
#    u'technical',
#    u'branding',
#    u'main',
#    u'page',
#    u'main',
#    u'page',
#    u'linked'),
#   3),
#  ((u'hearted',
#    u'without',
#    u'easy',
#    u'navigate',
#    u'site',
#    u'links',
#    u'right',
#    u'left'),
#   3),
#  ((u'graphics',
#    u'small',
#    u'fast-loading',
#    u'colors',
#    u'images',
#    u'go',
#    u'together',
#    u'nicely'),
#   3),
#  ...]

# %%
fdist1.plot(50, cumulative=True)
