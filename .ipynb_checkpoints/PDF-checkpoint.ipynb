# %%
import PyPDF2
import nltk
import matplotlib
import numpy
import os

# %%
pdfFiles = []
for filename in os.listdir('/home/neil//Downloads'):
    if filename.endswith('.pdf'):
        pdfFiles.append(filename)
pdfFiles.sort(key=str.lower)
print(pdfFiles)
# Out:
# ['Alignment_of_dates_for__making_good__on_benefits-in-kind_-_summary_of_responses.pdf', 'Consultation.pdf', 'Tackling_offshore_tax_evasion-a_requirement_to_correct_-_summary_of_responses.pdf', 'Tax_treatment_of_freeplays_in_Remote_Gaming_Duty_-_summary_of_responses.pdf', 'Technical_consultation_on_draft_regulations_for_the_apprenticeship_levy.pdf', 'Tobacco_Illicit_Trade_Protocol___licensing_of_equipment_and_the_supply_chain_-_summary_of_responses.pdf']

# %%
fullText = ""
for filename in pdfFiles:
    pdfFileObj = open('/home/neil//Downloads/' + filename, 'rb')
    pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
    for pageNum in range(1, pdfReader.numPages):
        pageObj = pdfReader.getPage(pageNum)
        pageText = pageObj.extractText()
        fullText += pageText
    print('/home/neil//Downloads/' + filename + "Added")

cText = fullText.replace('\n','')
# Out:
# /home/neil//Downloads/Alignment_of_dates_for__making_good__on_benefits-in-kind_-_summary_of_responses.pdfAdded
# /home/neil//Downloads/Consultation.pdfAdded
# /home/neil//Downloads/Tackling_offshore_tax_evasion-a_requirement_to_correct_-_summary_of_responses.pdfAdded
# /home/neil//Downloads/Tax_treatment_of_freeplays_in_Remote_Gaming_Duty_-_summary_of_responses.pdfAdded
# /home/neil//Downloads/Technical_consultation_on_draft_regulations_for_the_apprenticeship_levy.pdfAdded
# /home/neil//Downloads/Tobacco_Illicit_Trade_Protocol___licensing_of_equipment_and_the_supply_chain_-_summary_of_responses.pdfAdded

# %%
tokens = nltk.word_tokenize(cText)
text = nltk.Text(tokens)
print(text)
print('!!!!')
print(tokens)
# Out:
# <Text: 2 Contents 1 Introduction 2 Responses 3 Next...>
# !!!!
# ['2', 'Contents', '1', 'Introduction', '2', 'Responses', '3', 'Next', 'steps', '4', 'Annexe', 'A', ':', 'List', 'of', 'stakeholders', 'consulted', '...', '.10', 'On', 'request', 'this', 'document', 'can', 'be', 'produced', 'in', 'Welsh', 'and', 'alternative', 'formats', 'including', 'large', 'print', ',', 'audio', 'and', 'Braille', 'formats', '3', '1', '.', 'Introduction', 'Background', 'to', 'the', 'consultation', '1', '.', '1', 'Where', 'an', 'employee', 'receives', 'remuneration', 'from', 'their', 'employment', 'which', 'does', 'not', 'take', 'the', 'form', 'of', 'money', ',', 'this', 'is', 'known', 'as', 'a', 'benefit-in-kind', '.', 'Benefits-in-kind', 'are', 'ss', '1A', 'National', 'Insurance', 'contributions', '(', 'NICs', ')', '.', '1', '.', '2', 'The', 'cash', 'equivalent', 'of', 'the', 'benefit-in-kind', 'is', 'subject', 'to', 'tax', 'and', 'liable', 'to', 'NICs', '.', 'This', 'is', 'usually', 'calculated', 'as', 'the', 'cost', 'to', 'the', 'employer', 'of', 'providing', 'the', 'benefit-in-kind', ',', 'although', 'in', 'some', 'cases', 'it', 'is', 'calculated', 'in', 'a', 'different', 'way', '.', '1.3', 'Making', 'good', 'is', 'where', 'an', 'employee', 'gives', 'something', '(', 'usually', 'a', 'cash', 'payment', ')', 'to', 'the', 'person', 'providing', 'the', 'benefit-in-kind', 'in', 'return', 'for', 'it', '.', 'Making', 'good', 'has', 'the', 'effect', 'of', 'reducing', 'the', 'cash', 'equivalent', 'of', 'the', 'benefit-in-kind', ',', 'often', 'to', 'zero', '.', 'This', 'reduces', 'the', 'where', 'the', 'payment', 'is', 'made', 'within', 'certain', 'time', 'limits', '.', 'Where', 'an', 'employee', 'makes', 'a', 'payment', 'for', 'a', 'benefit-in-kind', 'under', 'salary', 'sacrifice', 'arrangements', ',', 'however', ',', 'this', 'does', 'not', 'qualify', 'as', 'a', 'making', 'good', 'payment', '.', '1.4', 'At', 'Budget', '2016', ',', 'the', 'government', 'announced', 'a', 'package', 'of', 'measures', 'to', 'simplify', 'further', 'the', 'tax', 'administration', 'of', 'employee', 'benefits', 'and', 'expenses', '.', 'The', 'package', 'included', 'a', 'commitment', 'to', 'consult', 'on', 'proposals', 'to', 'align', 'the', 'dates', 'by', 'which', 'an', 'employee', 'has', 'to', 'make', 'good', 'on', 'a', 'benefit-in-kind', 'in', 'order', 'to', 'reduce', 'or', 'remove', 'the', 'tax', 'charge', '.', '1.5', 'The', 'government', 'held', 'a', 'consultation', 'from', '9', 'August', 'to', '4', 'October', '2016', 'and', 'held', 'a', 'meeting', 'with', 'stakeholders', 'in', 'September', '.', 'This', 'document', 'summarises', 'the', 'responses', 'received', 'on', 'the', 'proposals', '.', '1.6', 'The', 'government', 'wishes', 'to', 'thank', 'all', 'those', 'who', 'took', 'the', 'time', 'to', 'send', 'in', 'written', 'responses', 'and', 'attend', 'the', 'meeting', '.', 'These', 'contributions', 'have', 'been', 'invaluable', 'in', 'informing', 'the', 'policy', '.', 'A', 'list', 'of', 'stakeholders', 'who', 'submitted', 'written', 'responses', 'and', 'attended', 'the', 'consultation', 'meeting', 'is', 'at', 'Annexe', 'A', '.', 'Aim', 'of', 'the', 'consultation', 'proposals', '1.7', 'There', 'are', 'different', 'dates', 'set', 'out', 'in', 'legislation', 'for', 'making', 'good', 'on', 'different', 'benefits-in-kind', 'in', 'order', 'to', 'reduce', 'or', 'remove', 'the', 'tax', 'charge', '.', 'For', 'some', 'benefits-in-kind', 'there', 'is', 'more', 'than', 'one', 'date', 'for', 'making', 'good', 'in', 'legislation', ',', 'whilst', 'for', 'others', 'there', 'is', 'no', 'statutory', 'date', '.', '1.8', 'Where', 'the', 'employer', 'voluntarily', 'accounts', 'for', 'the', 'benefit-in-kind', 'in', 'real', 'time', 'through', 'PAYE', '-in-kind', ')', 'the', 'legislative', 'framework', 'specifies', 'the', 'date', 'by', 'which', 'making', 'good', 'must', 'take', 'place', '.', 'This', 'is', 'the', 'end', 'of', 'the', 'tax', 'year', 'for', 'all', 'benefits-in-kind', 'other', 'than', 'fuel', 'benefit', 'for', 'which', 'making', 'good', 'must', 'take ...

# %%
len(text)
# Out:
# 26016

# %%
len(sorted(set(text)))
# Out:
# 3487

# %%
text.collocations()
# Out:
# salary sacrifice; apprenticeship levy; Government response; April
# 2017; draft legislation; reasonable excuse; making good; tax year;
# tobacco products; remote gaming; Trading Standards; sacrifice
# arrangements; consultation document; written responses; Government
# Response; draft regulations; tobacco manufacturing; September 2018;
# Finance Bill; manufacturing equipment

# %%
text.concordance("apprenticeship")

# %%
from nltk import FreqDist
from nltk import bigrams
from nltk import ngrams
n = 2
bgs = ngrams(tokens, n)
fdist1 = FreqDist(bgs)
print(fdist1)
# Out:
# <FreqDist with 14326 samples and 26015 outcomes>

# %%
fdist1.most_common(50)
# Out:
# [(('of', 'the'), 212),
#  (('.', 'The'), 91),
#  (('in', 'the'), 83),
#  (('to', 'the'), 82),
#  (('The', 'government'), 78),
#  (('that', 'the'), 68),
#  (('the', 'RTC'), 67),
#  (('for', 'the'), 63),
#  (('the', 'consultation'), 62),
#  (('will', 'be'), 61),
#  (('salary', 'sacrifice'), 56),
#  (('on', 'the'), 56),
#  ((',', 'the'), 52),
#  (('the', 'government'), 49),
#  (('should', 'be'), 47),
#  (('to', 'correct'), 47),
#  (('to', 'be'), 43),
#  (('the', 'tax'), 40),
#  (('with', 'the'), 40),
#  (('.', 'This'), 37),
#  (('would', 'be'), 36),
#  (('end', 'of'), 35),
#  (('the', 'end'), 34),
#  (('.', 'Government'), 34),
#  (('tax', 'and'), 33),
#  (('of', 'respondents'), 33),
#  (('of', 'a'), 32),
#  (('number', 'of'), 32),
#  ((',', 'and'), 30),
#  (('scope', 'of'), 30),
#  (('of', 'tobacco'), 30),
#  (('and', 'the'), 30),
#  (('the', 'taxpayer'), 29),
#  (('Annex', 'A'), 29),
#  (('tax', 'year'), 28),
#  (('those', 'who'), 28),
#  (('draft', 'legislation'), 27),
#  (('the', 'requirement'), 26),
#  (('apprenticeship', 'levy'), 26),
#  (('Government', 'response'), 25),
#  (('there', 'is'), 25),
#  (('.', 'In'), 25),
#  (('consultation', 'document'), 24),
#  (('government', 'has'), 24),
#  (('to', 'make'), 24),
#  (('to', 'ensure'), 24),
#  (('set', 'out'), 24),
#  (('the', 'scope'), 23),
#  (('.', 'They'), 23),
#  (('April', '2017'), 23)]

# %%
fdist1.plot(50, cumulative=True)

# %%
#from nltk import bigrams
from nltk import ngrams
n = 3
#list(bigrams(text))
list(ngrams(text, n))
